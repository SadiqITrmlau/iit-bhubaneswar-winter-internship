# %%
import pandas as pd
import json

# Load the CSV file
file_path = "final_7day_dataset.csv" #"modified_sample_54_UHRS_with_persona.csv"  # Update with the correct path if needed
df = pd.read_csv(file_path)

# Hardcoded row number (0-indexed)
row_number = 184  # Change this to the desired row number. For query in row X, make row_number = X-2

# Extract the reference_information column for the specified row
try:
    reference_data_1 = df.loc[row_number, "reference_information_1"]
    reference_data_2 = df.loc[row_number, "reference_information_2"]
    reference_data_3 = df.loc[row_number, "reference_information_3"]
    
    # Parse the JSON string into a Python object (list of dictionaries)
    parsed_data = json.loads(reference_data_1)
    parsed_data_2 = json.loads(reference_data_2)
    parsed_data_3 = json.loads(reference_data_3)
    
    # Ensure the data is a list of dictionaries
    if isinstance(parsed_data, list) and all(isinstance(d, dict) for d in parsed_data):
        print(f"Row {row_number+2} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

    if isinstance(parsed_data_2, list) and all(isinstance(d, dict) for d in parsed_data_2):
        # print(f"Row {row_number} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 9}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

    if isinstance(parsed_data_3, list) and all(isinstance(d, dict) for d in parsed_data_3):
        # print(f"Row {row_number} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data_3):
            print(f"\nEntry {idx + 15}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

except KeyError:
    print("Column 'reference_information' does not exist in the file.")
except IndexError:
    print(f"Row {row_number} does not exist in the file.")
except json.JSONDecodeError:
    print(f"Row {row_number} - 'reference_information' column is not a valid JSON string.")
# Out:
# Row 184 - Keys and Content in 'reference_information':
#
# Entry 1:
#   Description: Attractions in Corpus Christi
#   Content: name subcategories visit_duration address latitude longitude website
# Corpus Christi Museum of Science and History ['Museums'] 3.0 1900 N Chaparral St, Corpus Christi, TX 78401-1114 27.810104 -97.3953 http://www.ccmuseum.com
# The Selena Museum ['Museums'] 3.0 5410 Leopard St, Corpus Christi, TX 78408-2509 27.79811 -97.46123 https://q-productions.com/
# Malaquite Beach ['Nature & Parks', 'Outdoor Activities'] 4.25 20420 Park Road 22, Corpus Christi, TX 78418 27.424053 -97.29903 http://www.nps.gov/pais/index.htm
# The Grave of Selena Quintanilla-Perez ['Sights & Landmarks'] 3.0 4357 Ocean Dr Seaside Memorial Park, Corpus Christi, TX 78412-2532 27.732353 -97.362495
# Whitecap Beach ['Nature & Parks', 'Outdoor Activities'] 4.25 14802 Whitecap Blvd, Corpus Christi, TX 78418-7702 27.59847 -97.21166
# ...

# %% [markdown]
# # Row 79 Traveler Type: Adventure Seeker; Purpose of Travel: Nature; Spending Preference: Luxury Traveler; Location Preference: Beaches No. of Person: 1

# %% [markdown]
# import pandas as pd
# import json
#
# # Load the CSV file
# file_path = "final_7day_dataset.csv" #"modified_sample_54_UHRS_with_persona.csv"  # Update with the correct path if needed
# df = pd.read_csv(file_path)
#
# # Hardcoded row number (0-indexed)
# row_number = 77  # Change this to the desired row number. For query in row X, make row_number = X-2
#
# # Extract the reference_information column for the specified row
# try:
#     reference_data_1 = df.loc[row_number, "reference_information_1"]
#     reference_data_2 = df.loc[row_number, "reference_information_2"]
#     reference_data_3 = df.loc[row_number, "reference_information_3"]
#
#     # Parse the JSON string into a Python object (list of dictionaries)
#     parsed_data = json.loads(reference_data_1)
#     parsed_data_2 = json.loads(reference_data_2)
#     parsed_data_3 = json.loads(reference_data_3)
#
#     # Ensure the data is a list of dictionaries
#     if isinstance(parsed_data, list) and all(isinstance(d, dict) for d in parsed_data):
#         print(f"Row {row_number+2} - Keys and Content in 'reference_information':")
#         for idx, dictionary in enumerate(parsed_data):
#             print(f"\nEntry {idx + 1}:")
#             for key, value in dictionary.items():
#                 print(f"  {key}: {value}")
#     else:
#         print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")
#
#     if isinstance(parsed_data_2, list) and all(isinstance(d, dict) for d in parsed_data_2):
#         # print(f"Row {row_number} - Keys and Content in 'reference_information':")
#         for idx, dictionary in enumerate(parsed_data_2):
#             print(f"\nEntry {idx + 9}:")
#             for key, value in dictionary.items():
#                 print(f"  {key}: {value}")
#     else:
#         print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")
#
#     if isinstance(parsed_data_3, list) and all(isinstance(d, dict) for d in parsed_data_3):
#         # print(f"Row {row_number} - Keys and Content in 'reference_information':")
#         for idx, dictionary in enumerate(parsed_data_3):
#             print(f"\nEntry {idx + 15}:")
#             for key, value in dictionary.items():
#                 print(f"  {key}: {value}")
#     else:
#         print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")
#
# except KeyError:
#     print("Column 'reference_information' does not exist in the file.")
# except IndexError:
#     print(f"Row {row_number} does not exist in the file.")
# except json.JSONDecodeError:
#     print(f"Row {row_number} - 'reference_information' column is not a valid JSON string.")

# %%
import pandas as pd
import json

# Load the CSV file
file_path = "final_7day_dataset.csv"  # Update with the correct path if needed
df = pd.read_csv(file_path)

# Hardcoded row number (0-indexed)
row_number = 77  # Change this to the desired row number 79 here

# Extract the reference_information columns for the specified row
try:
    reference_data_1 = df.loc[row_number, "reference_information_1"]
    reference_data_2 = df.loc[row_number, "reference_information_2"]
    reference_data_3 = df.loc[row_number, "reference_information_3"]

    # Parse the JSON strings into Python objects (list of dictionaries)
    parsed_data = json.loads(reference_data_1)
    parsed_data_2 = json.loads(reference_data_2)
    parsed_data_3 = json.loads(reference_data_3)

    # Ensure the data is a list of dictionaries
    if isinstance(parsed_data, list) and all(isinstance(d, dict) for d in parsed_data):
        print(f"Row {row_number} - Keys and Content in 'reference_information_1':")
        for idx, dictionary in enumerate(parsed_data):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_1' is not a list of dictionaries.")

    if isinstance(parsed_data_2, list) and all(isinstance(d, dict) for d in parsed_data_2):
        print(f"\nRow {row_number} - Keys and Content in 'reference_information_2':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_2' is not a list of dictionaries.")

    if isinstance(parsed_data_3, list) and all(isinstance(d, dict) for d in parsed_data_2):
        print(f"\nRow {row_number} - Keys and Content in 'reference_information_3':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_3' is not a list of dictionaries.")    

    # Create the annotated travel plan with the adjusted format
    travel_plan = {
        "Day 1": {
            "Current City": "from Detroit to Memphis",
            "Transportation": "Flight Number: F1150616, from Detroit to Memphis, Departure Time: 08:34, Arrival Time: 09:24",
            "Breakfast": "Brother Juniper's, Memphis",
            "Attraction": "Memphis Riverboats, Memphis; Mud Island River Park, Memphis",
            "Lunch": "The Soul Fish Cafe Inc, Memphis",
            "Dinner": "Charles Vergos' Rendezvous, Memphis",
            "Accommodation": "Modern Midtown Pad (Queen real bed), Memphis", #hotel in 1st_dest_city
            "Event": "-",
            "Point of Interest List": [
                "Modern Midtown Pad (Queen real bed), stay from 09:30 to 10:30, nearest transit: CLEVELAND@LARKIN, 87.75m away;"
                "Brother Juniper's, visit from 10:30 to 11:30, nearest transit: SOUTHERN@ELLSWORTH, 199.70m away;"
                "Memphis Riverboats, visit from 11:30 to 14:30, nearest transit: RIVERSIDE DR @ COURT AVE, 213.38m away;"
                "The Soul Fish Cafe Inc, visit from 14:30 to 16:00, nearest transit: COOPER@NELSON AVE, 47.14m away;"
                "Mud Island River Park, visit from 16:00 to 18:00, nearest transit: FRONT@POPLAR, 539.88m away;"
                "Charles Vergos' Rendezvous, visit from 20:00 to 22:00, nearest transit: UNION AVE @ S 3RD ST, 102.45m away,"
                "Modern Midtown Pad (Queen real bed), stay from 22:30 to 09:00, nearest transit: CLEVELAND@LARKIN, 87.75m away."
            ]
        },
        # Add remaining days as needed
        "Day 2": {
                "Current City": "Memphis", #explore_1st_dest_city
                "Transportation": "-",
                "Breakfast": "Rum Boogie Cafe", #American
                "Attraction": "Memphis Zoo, Memphis; Backbeat Tours, Memphis",
                "Lunch": "Memphis BBQ Grill, Memphis",
                "Dinner": "Corky's Ribs & BBQ, Memphis",
                "Accommodation": "Modern Midtown Pad (Queen real bed), Memphis",
                "Event": "-",
                "Point of Interest List": [
                    "Modern Midtown Pad (Queen real bed), stay from 09:00 to 09:30, nearest transit: CLEVELAND@LARKIN, 87.75m away;" #1st  city hotel
                    " Rum Boogie Cafe, visit from 09:30 to 11:00, nearest transit: THIRD@PEABODYPL55, 30m away;"
                    " Memphis Zoo, visit from 11:00 to 13:30, nearest transit: N PARKWAY@WEST DR, 8.68m away;"
                    " Memphis BBQ Grill, visit from 13:30 to 15:00, nearest transit: BERRYHILL@STAGE, 9810764.39m away;"
                    " Backbeat Tours, visit from 15:00 to 18:30, nearest transit: THIRD@PEABODYPL, 78.56m away;"
                    " Corky's Ribs & BBQ, visit from 20:30 to 22:00, nearest transit: POPLAR@PELHAM DR, 43.73m away;"
                    " Modern Midtown Pad (Queen real bed), stay from 23:30 to 09:00, nearest transit: CLEVELAND@LARKIN, 87.75m away." #1st city hotel
                    
                ]
            },
            "Day 3": {
                "Current City": "from Memphis to Nashville", #travel from 1st_dest_city to 2nd_dest_city
                "Transportation": "Self-driving, Duration: 235.45 mins, Distance: 338.1372 km, Estimated Cost: $16.91", #we'll self deive from san luis obispo to san barbara 
                "Breakfast": "-", #skipped
                "Attraction": "Bass Pro Shops at the Pyramid, Memphis; Belmont Mansion, Nashville", # attraction in 1st destination city
                "Lunch": "Caney Fork River Valley Grille, Nashville", #lunch in 2nd destination city, mostly skipped due to travelling from dest_1 to dest_2
                "Dinner": "Harriet's Rooftop, Nashville", #lunch in 2nd dest city
                "Accommodation": " Dave's Place, Nashville", #accomodation in 2 destination city 
                "Event": "-",
                "Point of Interest List": [
                    "Modern Midtown Pad (Queen real bed), stay from 09:00 to 10:00, nearest transit: CLEVELAND@LARKIN, 87.75m away;" #city 1 hotel
                    " Bass Pro Shops at the Pyramid, stay from 10:00 to 11:30, nearest transit: BASS PRO SHOPS, 166.10m away;"
                    " Dave's Place, stay from 14:30 to 15:00, nearest transit: SHELBY AVE & S 8TH ST WB, 120.59m away;" #city 2 hotel; after reaching dest_2, get a hotel for your self
                    " Caney Fork River Valley Grille, visit from 15:00 to 16:00, nearest transit: MCGAVOCK PIKE & MUSIC VALLEY DR WB, 44.60m away;"
                    " Belmont Mansion, visit from 16:00 to 19:00, nearest transit: WEDGEWOOD AVE & 16TH AVE EB, 92.02m away;"
                    " Harriet's Rooftop, visit from 20:30 to 22:30, nearest transit: 8TH AVE S & DEMONBREUN ST SB, 66.96m away;"
                    " Dave's Place, stay from 22:30 to 09:00, nearest transit: SHELBY AVE & S 8TH ST WB, 120.59m away." #city 2 hotel
                    
                ]
            },
            "Day 4": {
                "Current City": "Nashville", #now in 2nd_dest city
                "Transportation": "-", #no travel today 
                "Breakfast" : "1 Kitchen, Nashville",
                "Attraction": "Radnor Lake Street Park, Nashville; Ole Smoky Distillery & Yee-Haw Brewery, Nashville; Cooter’s Museum and Store Nashville, Nashville",
                "Lunch": "-",
                "Dinner": "Luogo, Nashville",
                "Accommodation": "Dave's Place, Nashville",
                "Event": "-",
                "Point of Interest List": [
                    "Dave's Place, stay from 09:00 to 10:00, nearest transit: SHELBY AVE & S 8TH ST WB, 120.59m away;" #city 2 hotel
                    " 1 Kitchen, visit from 10:00 to 11:30, nearest transit: 8TH AVE S & DEMONBREUN ST SB, 67.82m away;"
                    " Radnor Lake State Park, visit from 11:30 to 14:00, nearest transit: SHACKLEFORD RD & BELMONT BLVD EB, 4533.45m away;"
                    " Ole Smoky Distillery & Yee-Haw Brewery, visit from 14:00 to 18:00, nearest transit: KOREAN VETS BLVD & 6TH AVE WB, 122.92m away;"
                    " Cooter’s Museum and Store Nashville, visit from 18:00 to 20:30, nearest transit: MCGAVOCK PIKE & MUSIC VALLEY DR WB, 109.02m away;"
                    " Luogo, visit from 20:30 to 22:00, nearest transit: 12TH AVE & LAUREL ST NB, 86.33m away;"
                    " Dave's Place, stay from 22:30 to 09:00, nearest transit: SHELBY AVE & S 8TH ST WB, 120.59m away." #city 2 hotel
                ]
            },
            "Day 5": {
                "Current City": "from Nashville to Bristol", #travel 2nd_dest_city to 3rd_dest_city
                "Transportation": "Self-driving, Duration: 319.115 mins, Distance: 467.80559999999997 km, Estimated Cost: $23.39", # remarks: not feasible to drive back from Santa Barbara to New York 
                "Breakfast": "-", #skipped breakfast
                "Attraction": "Bristol Museum & Art Gallery, Bristol",
                "Lunch": "Curry House, Bristol",
                "Dinner": "Aqua Welsh Back, Bristol",
                "Accommodation": " Sweet Bristol Bungalow , Bristol",
                "Event": "-",
                "Point of Interest List": [
                    "Dave's Place, stay from 09:00 to 09:30, nearest transit: SHELBY AVE & S 8TH ST WB, 120.59m away;" #city 2 hotel
                    #leaved fro 3rd_dest_city
                    " Sweet Bristol Bungalow, stay from 14:30 to 15:30, nearest transit: Oakview Ave & Hope Ln, 306.51m away;" # city 3 hotel
                    " Curry House, visit from 15:30 to 16:30, nearest transit: Home Depot, 6256796.42m away;"
                    " Bristol Museum & Art Gallery, visit from 16:30 to 19:00, nearest transit: Home Depot, 6253515.21m away;"
                    " Aqua Welsh Back, visit from 20:00 to 21:30, nearest transit: Home Depot, 6254458.49m away;"
                    " Sweet Bristol Bungalow, stay from 22:00 to 08:00 , nearest transit: Oakview Ave & Hope Ln, 306.51m away;" #city 3 hotel

                    
                ]
            },
        "Day 6": {
                "Current City": "Bristol", #now explore dest_city_3
                "Transportation": "-", #no travel today 
                "Breakfast" : "Blackbird Bakery, Bristol ",
                "Attraction": "Cycle the City, Bristol; Escape Hunt Bristol, Bristol; Cabot Tower, Bristol",
                "Lunch": "Three Brothers Burgers, Bristol",
                "Dinner": "Miller & Carter, Bristol",
                "Accommodation": "Sweet Bristol Bungalow, Bristol",
                "Event": "-",
                "Point of Interest List": [
                    "Sweet Bristol Bungalow, stay from 08:00 to 09:00, nearest transit: Salinas & Clifton, 819.76m away;" #city 3 hotel
                    " Blackbird Bakery, visit from 09:00 to 10:00, nearest transit: Cumberland St & Waters Alley, 84.53m away;"
                    " Cycle the City, visit from 10:00 to 13:00, nearest transit: Home Depot, 6254128.85m away;"
                    " Three Brothers Burgers, visit from 13:00 to 15:00, nearest transit: Home Depot, 6254486.64m away;"
                    " Escape Hunt Bristol, visit from 15:00 to 18:00, nearest transit: Home Depot, 6254741.37m away;"
                    " Cabot Tower, visit from 18:00 to 20:00, nearest transit: Home Depot, 6253464.57m away;"
                    " Miller & Carter, visit from 20:00 to 22:00, nearest transit: Home Depot, 6254038.48m away;"
                    " Sweet Bristol Bungalow, stay from 22:30 to 09:00, nearest transit: Salinas & Clifton, 819.76m away." #city 3 hotel
                ]
            },
        "Day 7": {
                "Current City": "from Bristol to Detroit", #from 3rd_dest_city to origin_city
                "Transportation": "Self-driving, Duration: 643.0699999999999 mins, Distance: 840.4791 km, Estimated Cost: $42.02", # remarks:  feasible to drive 
                "Breakfast": "Baba Ganoush Kitchen - Jerusalem Falafel, Bristol",
                "Attraction": "Clifton Suspension Bridge, Bristol",
                "Lunch": "Don Giovanni's Restaurant, Bristol",
                "Dinner": "-",
                "Accommodation": "Sweet Bristol Bungalow, Bristol",
                "Event": "-",
                "Point of Interest List": [
                    "Sweet Bristol Bungalow, Bristol, stay from 09:00 to 10:00, nearest transit: Salinas & Clifton, 819.76m away;" #city 3 hotel
                    " Baba Ganoush Kitchen - Jerusalem Falafel, visit from 10:00 to 11:30, nearest transit: Home Depot, 6254988.11m away;"
                    " Clifton Suspension Bridge, vist from 11:30 to 14:00, nearest transit: Home Depot, 6252045.82m away;"
                    " Don Giovanni's Restaurant, visit from 14:00 to 16:00, nearest transit: Home Depot, 6255251.85m away."
                ]
        
    }

        
              

        
        # Add remaining days as needed
    }

    # Print the travel plan
    print("\nAnnotated Travel Plan:")
    for day, details in travel_plan.items():
        print(f"\n{day}:")
        for key, value in details.items():
            if isinstance(value, list):
                print(f"{key}:")
                for item in value:
                    print(f"  {item}")
            else:
                print(f"{key}: {value}")

except KeyError:
    print("Column 'reference_information' does not exist in the file.")
except IndexError:
    print(f"Row {row_number} does not exist in the file.")
except json.JSONDecodeError as e:
    print(f"JSON decoding error for row {row_number}: {e}")
# Out:
# Row 77 - Keys and Content in 'reference_information_1':
#
# Entry 1:
#   Description: Attractions in Memphis
#   Content: name subcategories visit_duration address latitude longitude website
# AutoZone Park ['Sights & Landmarks'] 3.0 Union Ave and Third Ave, Memphis, TN 38103 35.142677 -90.049995 https://www.milb.com/memphis/ballpark/autozone-park
# Memphis City Tour with Optional Riverboat Cruise & Sun Studio Add-On Options []  Memphis, TN
# Main Street Trolley ['Tours', 'Transportation'] 2.25 Main St and Riverfront, Memphis, TN 38103 35.15905 -90.04797 http://www.matatransit.com/services/trolleys/
# Memphis Riverboats ['Tours', 'Boat Tours & Water Sports', 'Outdoor Activities'] 3.5 45 S Riverside Dr Beale Street Landing, Memphis, TN 38103-2421 35.144867 -90.05629 http://www.memphisriverboats.net/
# Backbeat Tours ['Tours', 'Outdoor Activities'] 3.5 197 Beale St on the patio at Alfred's on Beale, Memphis, TN 38103-3128 35.139446 -90.051735 http://www.backbeattours.com/
# ...

# %% [markdown]
# # Row 80 Traveler Type: Adventure Seeker; Purpose of Travel: Cultural Exploration; Spending Preference: Luxury Traveler; Location Preference: Beaches

# %%
import pandas as pd
import json

# Load the CSV file
file_path = "final_7day_dataset.csv" #"modified_sample_54_UHRS_with_persona.csv"  # Update with the correct path if needed
df = pd.read_csv(file_path)

# Hardcoded row number (0-indexed)
row_number = 78  # Change this to the desired row number. For query in row X, make row_number = X-2

# Extract the reference_information column for the specified row
try:
    reference_data_1 = df.loc[row_number, "reference_information_1"]
    reference_data_2 = df.loc[row_number, "reference_information_2"]
    reference_data_3 = df.loc[row_number, "reference_information_3"]
    
    # Parse the JSON string into a Python object (list of dictionaries)
    parsed_data = json.loads(reference_data_1)
    parsed_data_2 = json.loads(reference_data_2)
    parsed_data_3 = json.loads(reference_data_3)
    
    # Ensure the data is a list of dictionaries
    if isinstance(parsed_data, list) and all(isinstance(d, dict) for d in parsed_data):
        print(f"Row {row_number+2} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

    if isinstance(parsed_data_2, list) and all(isinstance(d, dict) for d in parsed_data_2):
        # print(f"Row {row_number} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 9}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

    if isinstance(parsed_data_3, list) and all(isinstance(d, dict) for d in parsed_data_3):
        # print(f"Row {row_number} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data_3):
            print(f"\nEntry {idx + 15}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

except KeyError:
    print("Column 'reference_information' does not exist in the file.")
except IndexError:
    print(f"Row {row_number} does not exist in the file.")
except json.JSONDecodeError:
    print(f"Row {row_number} - 'reference_information' column is not a valid JSON string.")
# Out:
# Row 80 - Keys and Content in 'reference_information':
#
# Entry 1:
#   Description: Attractions in Memphis
#   Content: name subcategories visit_duration address latitude longitude website
# AutoZone Park ['Sights & Landmarks'] 3.0 Union Ave and Third Ave, Memphis, TN 38103 35.142677 -90.049995 https://www.milb.com/memphis/ballpark/autozone-park
# Memphis City Tour with Optional Riverboat Cruise & Sun Studio Add-On Options []  Memphis, TN
# Main Street Trolley ['Tours', 'Transportation'] 2.25 Main St and Riverfront, Memphis, TN 38103 35.15905 -90.04797 http://www.matatransit.com/services/trolleys/
# Memphis Riverboats ['Tours', 'Boat Tours & Water Sports', 'Outdoor Activities'] 3.5 45 S Riverside Dr Beale Street Landing, Memphis, TN 38103-2421 35.144867 -90.05629 http://www.memphisriverboats.net/
# Backbeat Tours ['Tours', 'Outdoor Activities'] 3.5 197 Beale St on the patio at Alfred's on Beale, Memphis, TN 38103-3128 35.139446 -90.051735 http://www.backbeattours.com/
# ...

# %%
import pandas as pd
import json

# Load the CSV file
file_path = "final_7day_dataset.csv"  # Update with the correct path if needed
df = pd.read_csv(file_path)

# Hardcoded row number (0-indexed)
row_number = 78  # Change this to the desired row number 79 here

# Extract the reference_information columns for the specified row
try:
    reference_data_1 = df.loc[row_number, "reference_information_1"]
    reference_data_2 = df.loc[row_number, "reference_information_2"]
    reference_data_3 = df.loc[row_number, "reference_information_3"]

    # Parse the JSON strings into Python objects (list of dictionaries)
    parsed_data = json.loads(reference_data_1)
    parsed_data_2 = json.loads(reference_data_2)
    parsed_data_3 = json.loads(reference_data_3)

    # Ensure the data is a list of dictionaries
    if isinstance(parsed_data, list) and all(isinstance(d, dict) for d in parsed_data):
        print(f"Row {row_number} - Keys and Content in 'reference_information_1':")
        for idx, dictionary in enumerate(parsed_data):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_1' is not a list of dictionaries.")

    if isinstance(parsed_data_2, list) and all(isinstance(d, dict) for d in parsed_data_2):
        print(f"\nRow {row_number} - Keys and Content in 'reference_information_2':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_2' is not a list of dictionaries.")

    if isinstance(parsed_data_3, list) and all(isinstance(d, dict) for d in parsed_data_2):
        print(f"\nRow {row_number} - Keys and Content in 'reference_information_3':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_3' is not a list of dictionaries.")    

    # Create the annotated travel plan with the adjusted format
    travel_plan = {
        "Day 1": {
            "Current City": "from Key West to Memphis",
            "Transportation": "Self-driving, Duration: 1354.8933333333334 mins, Distance: 1827.3601 km, Estimated Cost: $91.37",
            "Breakfast": "Brother Juniper's, Memphis",
            "Attraction": "Memphis Riverboats, Memphis; National Civil Rights Museum - Lorraine Motel, Memphis",
            "Lunch": "The Soul Fish Cafe Inc, Memphis",
            "Dinner": "Charles Vergos' Rendezvous, Memphis",
            "Accommodation": "Modern Midtown Pad (Queen real bed), Memphis", #hotel in 1st_dest_city
            "Event": "-",
            "Point of Interest List": [
                "Modern Midtown Pad (Queen real bed), stay from 09:30 to 10:30, nearest transit: CLEVELAND@LARKIN, 87.75m away;"
                "Brother Juniper's, visit from 10:30 to 11:30, nearest transit: SOUTHERN@ELLSWORTH, 199.70m away;"
                "Memphis Riverboats, visit from 11:30 to 14:30, nearest transit: RIVERSIDE DR @ COURT AVE, 213.38m away;"
                "The Soul Fish Cafe Inc, visit from 14:30 to 16:00, nearest transit: COOPER@NELSON AVE, 47.14m away;"
                "National Civil Rights Museum - Lorraine Motel, visit from 16:00 to 19:00, nearest transit: SECOND@BULTER, 96.55m away;"
                "Charles Vergos' Rendezvous, visit from 20:00 to 22:00, nearest transit: UNION AVE @ S 3RD ST, 102.45m away,"
                "Modern Midtown Pad (Queen real bed), stay from 22:30 to 09:00, nearest transit: CLEVELAND@LARKIN, 87.75m away."
            ]
        },
        # Add remaining days as needed
        "Day 2": {
                "Current City": "Memphis", #explore_1st_dest_city
                "Transportation": "-",
                "Breakfast": "Rum Boogie Cafe", #American
                "Attraction": "Graceland, Memphis; Backbeat Tours, Memphis",
                "Lunch": "Memphis BBQ Grill, Memphis",
                "Dinner": "Corky's Ribs & BBQ, Memphis",
                "Accommodation": "Modern Midtown Pad (Queen real bed), Memphis",
                "Event": "-",
                "Point of Interest List": [
                    "Modern Midtown Pad (Queen real bed), stay from 09:00 to 09:30, nearest transit: CLEVELAND@LARKIN, 87.75m away;" #1st  city hotel
                    " Rum Boogie Cafe, visit from 09:30 to 11:00, nearest transit: THIRD@PEABODYPL55, 30m away;"
                    " Graceland, visit from 11:00 to 13:30, nearest trasnit: ELVIS PRESLEY BLVD@DOLAN DR, 199.90m away;"
                    " Memphis BBQ Grill, visit from 13:30 to 15:00, nearest transit: BERRYHILL@STAGE, 9810764.39m away;"
                    " Backbeat Tours, visit from 15:00 to 18:30, nearest transit: THIRD@PEABODYPL, 78.56m away;"
                    " Corky's Ribs & BBQ, visit from 20:30 to 22:00, nearest transit: POPLAR@PELHAM DR, 43.73m away;"
                    " Modern Midtown Pad (Queen real bed), stay from 23:30 to 09:00, nearest transit: CLEVELAND@LARKIN, 87.75m away." #1st city hotel
                    
                ]
            },
            "Day 3": {
                "Current City": "from Memphis to Bristol", #travel from 1st_dest_city to 2nd_dest_city
                "Transportation": "Self-driving, Duration: 553.0733333333334 mins, Distance: 805.7771 km, Estimated Cost: $40.29", #we'll self deive from san luis obispo to san barbara 
                "Breakfast": "-", #skipped breakfast
                "Attraction": "Bristol Museum & Art Gallery, Bristol",
                "Lunch": "Curry House, Bristol",
                "Dinner": "Aqua Welsh Back, Bristol",
                "Accommodation": " Sweet Bristol Bungalow , Bristol",
                "Event": "-",
                "Point of Interest List": [
                    "Modern Midtown Pad (Queen real bed), stay from 09:00 to 10:00, nearest transit: CLEVELAND@LARKIN, 87.75m away;" #city 2 hotel
                    " Gibson's Donuts, visit from 10:00 to 11:00, nearest transit: POPLAR@TRUSE PKWY, 224.02m away"
                    #leaved from 3rd_dest_city
                    " Sweet Bristol Bungalow, stay from 14:30 to 15:30, nearest transit: Oakview Ave & Hope Ln, 306.51m away;" # city 3 hotel
                    " Curry House, visit from 15:30 to 16:30, nearest transit: Home Depot, 6256796.42m away;"
                    " Bristol Museum & Art Gallery, visit from 16:30 to 19:00, nearest transit: Home Depot, 6253515.21m away;"
                    " Aqua Welsh Back, visit from 20:00 to 21:30, nearest transit: Home Depot, 6254458.49m away;"
                    " Sweet Bristol Bungalow, stay from 22:00 to 08:00 , nearest transit: Oakview Ave & Hope Ln, 306.51m away;" #city 2 hotel
                    
                ]
            },
            "Day 4": {
                "Current City": "Bristol", #now explore dest_city_3
                "Transportation": "-", #no travel today 
                "Breakfast" : "Blackbird Bakery, Bristol ",
                "Attraction": "Brunel's SS Great Britain, Bristol; Escape Hunt Bristol, Bristol; Cabot Tower, Bristol",
                "Lunch": "Three Brothers Burgers, Bristol",
                "Dinner": "Miller & Carter, Bristol",
                "Accommodation": "Sweet Bristol Bungalow, Bristol",
                "Event": "-",
                "Point of Interest List": [
                    "Sweet Bristol Bungalow, stay from 08:00 to 09:00, nearest transit: Salinas & Clifton, 819.76m away;" #city 3 hotel
                    " Blackbird Bakery, visit from 09:00 to 10:00, nearest transit: Cumberland St & Waters Alley, 84.53m away;"
                    " Cycle the City, visit from 10:00 to 13:00, nearest transit: Home Depot, 6254128.85m away;"
                    " Three Brothers Burgers, visit from 13:00 to 15:00, nearest transit: Home Depot, 6254486.64m away;"
                    " Brunel's SS Great Britain, visit from 15:00 to 18:00, nearest transit: Home Depot, 6253545.34m away;"
                    " Cabot Tower, visit from 18:00 to 20:00, nearest transit: Home Depot, 6253464.57m away;"
                    " Miller & Carter, visit from 20:00 to 22:00, nearest transit: Home Depot, 6254038.48m away;"
                    " Sweet Bristol Bungalow, stay from 22:30 to 09:00, nearest transit: Salinas & Clifton, 819.76m away." #city 2 hotel
                ]
            },
            "Day 5": {
                "Current City": "from Bristol to Nashville", #travel 2nd_dest_city to 3rd_dest_city
                "Transportation": "Self-driving, Duration: 318.82666666666665 mins, Distance: 467.26559999999995 km, Estimated Cost: $23.36", # remarks: not feasible to drive back from Santa Barbara to New York 
                "Breakfast": "Rum Boogie Cafe, Bristol", #skipped breakfast
                "Attraction": "Bristol Museum & Art Gallery, Bristol; Tennessee State Museum, Nashville",
                "Lunch": " The Chef And I, Nashville",
                "Dinner": " Smiling Elephant, Nashville",
                "Accommodation": "Roomy Bungalow., Nashville",
                "Event": "-",
                "Point of Interest List": [
                    "Sweet Bristol Bungalow, stay from 08:00 to 09:00, nearest transit: Salinas & Clifton, 819.76m away;" #city 2 hotel
                    " Rum Boogie Cafe, visit from 09:00 to 10:00, nearest transit: THIRD@PEABODYPL55, 30m away;"
                    " Bristol Museum & Art Gallery, visit from 11:00 to 12:30, nearest transit: Home Depot, 6253515.21m away;"
                    #leaved fro 3rd_dest_city i.e Nashville
                    " Roomy Bungalow., stay from 14:00 to 14:30, nearest trasnit: WEDGEWOOD AVE & HILLSIDE AVE WB, 48.78m away;" # city 3 hotel
                    " The Chef And I, visit from 14:30 to 16:00, nearest trasnit: 21ST AVE & BROADWAY AVE SB, 157.63m away;"
                    " Tennessee State Museum, visit from 16:00 to 18:30, nearest transit: 8TH AVE N & JEFFERSON ST SB, 40.17m away;"
                    
                    " Smiling Elephant, visit from 20:00 to 21:30, nearest trasnit: 8TH AVE S & BRADFORD AVE SB, 66.14m away;"
                    " Roomy Bungalow., stay from 22:00 to 08:30, nearest trasnit: WEDGEWOOD AVE & HILLSIDE AVE WB, 48.78m away;" #city 3 hotel

                    
                ]
            },
        "Day 6": {
                "Current City": "Nashville", #now in 2nd_dest city
                "Transportation": "-", #no travel today 
                "Breakfast" : "1 Kitchen, Nashville",
                "Attraction": "Radnor Lake Street Park, Nashville; Ole Smoky Distillery & Yee-Haw Brewery, Nashville; Cooter’s Museum and Store Nashville, Nashville",
                "Lunch": "-",
                "Dinner": "Luogo, Nashville",
                "Accommodation": "Roomy Bungalow., Nashville",
                "Event": "-",
                "Point of Interest List": [
                    "Roomy Bungalow., stay from 08:30 to 09:30, nearest trasnit: WEDGEWOOD AVE & HILLSIDE AVE WB, 48.78m away;" #city 2 hotel
                    " 1 Kitchen, visit from 10:00 to 11:30, nearest transit: 8TH AVE S & DEMONBREUN ST SB, 67.82m away;"
                    " Radnor Lake State Park, visit from 11:30 to 14:00, nearest transit: SHACKLEFORD RD & BELMONT BLVD EB, 4533.45m away;"
                    " Ole Smoky Distillery & Yee-Haw Brewery, visit from 14:00 to 18:00, nearest transit: KOREAN VETS BLVD & 6TH AVE WB, 122.92m away;"
                    " Cooter’s Museum and Store Nashville, visit from 18:00 to 20:30, nearest transit: MCGAVOCK PIKE & MUSIC VALLEY DR WB, 109.02m away;"
                    " Luogo, visit from 20:30 to 22:00, nearest transit: 12TH AVE & LAUREL ST NB, 86.33m away;"
                    " Roomy Bungalow., stay from 22:30 to 09:00, nearest trasnit: WEDGEWOOD AVE & HILLSIDE AVE WB, 48.78m away." #city 3 hotel
                ]
            },
        "Day 7": {
                "Current City": "from Nashville to Key West", #from 3rd_dest_city to origin_city
                "Transportation": "Self-driving, Duration: 1229.4350000000002 mins, Distance: 1716.1214 km, Estimated Cost: $85.81", # remarks:  feasible to drive 
                "Breakfast": "The Bluebird Cafe, Nashville",
                "Attraction": "Andrew Jackson's Hermitage, Nashville",
                "Lunch": "",
                "Dinner": "-",
                "Accommodation": "Roomy Bungalow., Nashville",
                "Event": "West Virginia Mountaineers Mens Basketball vs. UMass Minutemen Mens Basketball Sports 401 Grand Central Station Dr 2024-11-08",
                "Point of Interest List": [
                    "Roomy Bungalow., stay from 09:00 to 10:00, nearest trasnit: WEDGEWOOD AVE & HILLSIDE AVE WB, 48.78m away;" #city 3 hotel
                    " The Bluebird Cafe, visit from 10:00 to 11:30, nearest transit: RICHARD JONES RD & HILLSBORO PIKE W, 383.04m away;"
                    " Andrew Jackson's Hermitage, visit from 11:30 to 13:00, nearest transit: LEBANON PIKE & MONACO DR SB, 929.39m away."
                ]
        
    }

        
              

        
        # Add remaining days as needed
    }

    # Print the travel plan
    print("\nAnnotated Travel Plan:")
    for day, details in travel_plan.items():
        print(f"\n{day}:")
        for key, value in details.items():
            if isinstance(value, list):
                print(f"{key}:")
                for item in value:
                    print(f"  {item}")
            else:
                print(f"{key}: {value}")

except KeyError:
    print("Column 'reference_information' does not exist in the file.")
except IndexError:
    print(f"Row {row_number} does not exist in the file.")
except json.JSONDecodeError as e:
    print(f"JSON decoding error for row {row_number}: {e}")
# Out:
# Row 78 - Keys and Content in 'reference_information_1':
#
# Entry 1:
#   Description: Attractions in Memphis
#   Content: name subcategories visit_duration address latitude longitude website
# AutoZone Park ['Sights & Landmarks'] 3.0 Union Ave and Third Ave, Memphis, TN 38103 35.142677 -90.049995 https://www.milb.com/memphis/ballpark/autozone-park
# Memphis City Tour with Optional Riverboat Cruise & Sun Studio Add-On Options []  Memphis, TN
# Main Street Trolley ['Tours', 'Transportation'] 2.25 Main St and Riverfront, Memphis, TN 38103 35.15905 -90.04797 http://www.matatransit.com/services/trolleys/
# Memphis Riverboats ['Tours', 'Boat Tours & Water Sports', 'Outdoor Activities'] 3.5 45 S Riverside Dr Beale Street Landing, Memphis, TN 38103-2421 35.144867 -90.05629 http://www.memphisriverboats.net/
# Backbeat Tours ['Tours', 'Outdoor Activities'] 3.5 197 Beale St on the patio at Alfred's on Beale, Memphis, TN 38103-3128 35.139446 -90.051735 http://www.backbeattours.com/
# ...

# %% [markdown]
# # Row 81 Traveler Type: Laidback Traveler; Purpose of Travel: Relaxation; Spending Preference: Economical Traveler; Location Preference: Cities

# %%
import pandas as pd
import json

# Load the CSV file
file_path = "final_7day_dataset.csv" #"modified_sample_54_UHRS_with_persona.csv"  # Update with the correct path if needed
df = pd.read_csv(file_path)

# Hardcoded row number (0-indexed)
row_number = 79  # Change this to the desired row number. For query in row X, make row_number = X-2

# Extract the reference_information column for the specified row
try:
    reference_data_1 = df.loc[row_number, "reference_information_1"]
    reference_data_2 = df.loc[row_number, "reference_information_2"]
    reference_data_3 = df.loc[row_number, "reference_information_3"]
    
    # Parse the JSON string into a Python object (list of dictionaries)
    parsed_data = json.loads(reference_data_1)
    parsed_data_2 = json.loads(reference_data_2)
    parsed_data_3 = json.loads(reference_data_3)
    
    # Ensure the data is a list of dictionaries
    if isinstance(parsed_data, list) and all(isinstance(d, dict) for d in parsed_data):
        print(f"Row {row_number+2} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

    if isinstance(parsed_data_2, list) and all(isinstance(d, dict) for d in parsed_data_2):
        # print(f"Row {row_number} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 9}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

    if isinstance(parsed_data_3, list) and all(isinstance(d, dict) for d in parsed_data_3):
        # print(f"Row {row_number} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data_3):
            print(f"\nEntry {idx + 15}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

except KeyError:
    print("Column 'reference_information' does not exist in the file.")
except IndexError:
    print(f"Row {row_number} does not exist in the file.")
except json.JSONDecodeError:
    print(f"Row {row_number} - 'reference_information' column is not a valid JSON string.")
# Out:
# Row 81 - Keys and Content in 'reference_information':
#
# Entry 1:
#   Description: Attractions in Nashville
#   Content: name subcategories visit_duration address latitude longitude website
# Belmont Mansion ['Sights & Landmarks', 'Nature & Parks'] 3.75 Acklen Avenue at Belmont Blvd, Nashville, TN 37212-3810 36.135468 -86.79476 http://www.belmontmansion.com
# Lane Motor Museum ['Museums'] 3.0 702 Murfreesboro Pike, Nashville, TN 37210-4522 36.140305 -86.73423 http://www.lanemotormuseum.org/
# Musicians Hall of Fame and Museum ['Museums'] 3.0 401 Gay St, Nashville, TN 37219 36.16793 -86.782524 http://www.musicianshalloffame.com/
# Bridgestone Arena ['Sights & Landmarks'] 3.0 501 Broadway 41415 Justin Clinton Twp. Mi.48038, Nashville, TN 37203-3932 36.159214 -86.77849 http://www.bridgestonearena.com
# Cheekwood ['Sights & Landmarks', 'Museums', 'Nature & Parks'] 3.5 1200 Forrest Park Dr, Nashville, TN 37205-4206 36.088448 -86.87598 http://www.cheekwood.org
# ...

# %%
import pandas as pd
import json

# Load the CSV file
file_path = "final_7day_dataset.csv"  # Update with the correct path if needed
df = pd.read_csv(file_path)

# Hardcoded row number (0-indexed)
row_number = 78  # Change this to the desired row number 79 here

# Extract the reference_information columns for the specified row
try:
    reference_data_1 = df.loc[row_number, "reference_information_1"]
    reference_data_2 = df.loc[row_number, "reference_information_2"]
    reference_data_3 = df.loc[row_number, "reference_information_3"]

    # Parse the JSON strings into Python objects (list of dictionaries)
    parsed_data = json.loads(reference_data_1)
    parsed_data_2 = json.loads(reference_data_2)
    parsed_data_3 = json.loads(reference_data_3)

    # Ensure the data is a list of dictionaries
    if isinstance(parsed_data, list) and all(isinstance(d, dict) for d in parsed_data):
        print(f"Row {row_number} - Keys and Content in 'reference_information_1':")
        for idx, dictionary in enumerate(parsed_data):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_1' is not a list of dictionaries.")

    if isinstance(parsed_data_2, list) and all(isinstance(d, dict) for d in parsed_data_2):
        print(f"\nRow {row_number} - Keys and Content in 'reference_information_2':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_2' is not a list of dictionaries.")

    if isinstance(parsed_data_3, list) and all(isinstance(d, dict) for d in parsed_data_2):
        print(f"\nRow {row_number} - Keys and Content in 'reference_information_3':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_3' is not a list of dictionaries.")    

    # Create the annotated travel plan with the adjusted format
    travel_plan = {
        "Day 1": {
            "Current City": "from Raleigh to Nashville",
            "Transportation": "Flight Number: F1700909, from Raleigh to Nashville, Departure Time: 08:28, Arrival Time: 08:53",
            "Breakfast": "The Bluebird Cafe, Nashville", #skipped
            "Attraction": "Bridgestone Arena, Nashville; Downtown Nashville, Nashville", # attraction in 1st destination city
            "Lunch": "Caney Fork River Valley Grille, Nashville", #lunch in 2nd destination city, mostly skipped due to travelling from dest_1 to dest_2
            "Dinner": "The Stillery, Nashville", #lunch in 2nd dest city
            "Accommodation": "Private Entrance near Airport in Safe neighborhood, Nashville", #accomodation in 2 destination city 
            "Event": "-",
            "Point of Interest List": [
                "Private Entrance near Airport in Safe neighborhood, stay from 09:00 to 10:00, nearest transit: LEBANON PIKE & DANYACREST DR SB, 295.08m away;"
                " The Bluebird Cafe, visit from 10:00 to 11:30, nearest transit: RICHARD JONES RD & HILLSBORO PIKE W, 383.04m away;"
                " Bridgestone Arena, visit from: 11:30 to 13:00, nearest trasnit: CONVENTION CENTER STATION OUTBOUND, 212.95m away;"
                " Caney Fork River Valley Grille, visit from 13:00 to 14:30, nearest transit: MCGAVOCK PIKE & MUSIC VALLEY DR WB, 44.60m away;"
                " Downtown Nashville, visit from 15:00 to 18:00, nearest trasnit: 5TH AVE N & COMMERCE ST NB, 140.94m away;"
                " The Stillery, visit from 19:30 to 21:30, nearest transit: BROADWAY AVE & 2ND AVE N WB, 59.97m away;"
                " Private Entrance near Airport in Safe neighborhood, stay from 22:00 to 09:00, nearest transit: LEBANON PIKE & DANYACREST DR SB, 295.08m away."
            ]
        },
        # Add remaining days as needed
        "Day 2": {
                "Current City": "Nashville", #now in 2nd_dest city
                "Transportation": "-", #no travel today 
                "Breakfast" : "1 Kitchen, Nashville",
                "Attraction": "Radnor Lake Street Park, Nashville; Ole Smoky Distillery & Yee-Haw Brewery, Nashville; Cooter’s Museum and Store Nashville, Nashville",
                "Lunch": "Skull's Rainbow Room, Nashville",
                "Dinner": "Luogo, Nashville",
                "Accommodation": "Private Entrance near Airport in Safe neighborhood, Nashville",
                "Event": "-",
                "Point of Interest List": [
                    "Private Entrance near Airport in Safe neighborhood, stay from 09:00 to 10:00, nearest transit: LEBANON PIKE & DANYACREST DR SB, 295.08m away;" #city 2 hotel
                    " 1 Kitchen, visit from 10:00 to 11:30, nearest transit: 8TH AVE S & DEMONBREUN ST SB, 67.82m away;"
                    " Radnor Lake State Park, visit from 11:30 to 14:00, nearest transit: SHACKLEFORD RD & BELMONT BLVD EB, 4533.45m away;"
                    " Skull's Rainbow Room, visit from 14:00 to 15:30, nearest transit: 4TH AVE N & CHURCH ST SB, 83.81m away;"
                    " Ole Smoky Distillery & Yee-Haw Brewery, visit from 15:30 to 18:00, nearest transit: KOREAN VETS BLVD & 6TH AVE WB, 122.92m away;"
                    
                    " Cooter’s Museum and Store Nashville, visit from 18:00 to 20:30, nearest transit: MCGAVOCK PIKE & MUSIC VALLEY DR WB, 109.02m away;"
                    " Luogo, visit from 20:30 to 22:00, nearest transit: 12TH AVE & LAUREL ST NB, 86.33m away;"
                    " Private Entrance near Airport in Safe neighborhood, stay from 22:00 to 09:00, nearest transit: LEBANON PIKE & DANYACREST DR SB, 295.08m away." #1st city hotel
                    
                ]
            },
            "Day 3": {
                "Current City": "from Nashville to Bristol", #travel from 1st_dest_city to 2nd_dest_city
                "Transportation": "Self-driving, Duration: 553.0733333333334 mins, Distance: 805.7771 km, Estimated Cost: $40.29", #we'll self deive from san luis obispo to san barbara 
                "Breakfast": "Harriet's Rooftop, Nashville", #skipped breakfast
                "Attraction": "Bristol Museum & Art Gallery, Bristol",
                "Lunch": "Curry House, Bristol",
                "Dinner": "Aqua Welsh Back, Bristol",
                "Accommodation": " Sweet Bristol Bungalow , Bristol",
                "Event": "-",
                "Point of Interest List": [
                    "Private Entrance near Airport in Safe neighborhood, stay from 09:00 to 10:00, nearest transit: LEBANON PIKE & DANYACREST DR SB, 295.08m away;" #city 2 hotel
                    " Harriet's Rooftop, visit from 10:00 to 11:30, nearest transit: 8TH AVE S & DEMONBREUN ST SB, 66.96m away"
                    #leaved from 3rd_dest_city
                    " Sweet Bristol Bungalow, stay from 14:30 to 15:30, nearest transit: Oakview Ave & Hope Ln, 306.51m away;" # city 3 hotel
                    " Curry House, visit from 15:30 to 16:30, nearest transit: Home Depot, 6256796.42m away;"
                    " Bristol Museum & Art Gallery, visit from 16:30 to 19:00, nearest transit: Home Depot, 6253515.21m away;"
                    " Aqua Welsh Back, visit from 20:00 to 21:30, nearest transit: Home Depot, 6254458.49m away;"
                    " Sweet Bristol Bungalow, stay from 22:00 to 08:00 , nearest transit: Oakview Ave & Hope Ln, 306.51m away;" #city 2 hotel
                    
                ]
            },
            "Day 4": {
                "Current City": "Bristol", #now explore dest_city_3
                "Transportation": "-", #no travel today 
                "Breakfast" : "Blackbird Bakery, Bristol ",
                "Attraction": "Brunel's SS Great Britain, Bristol; Escape Hunt Bristol, Bristol; Cabot Tower, Bristol",
                "Lunch": "Three Brothers Burgers, Bristol",
                "Dinner": "Miller & Carter, Bristol",
                "Accommodation": "Sweet Bristol Bungalow, Bristol",
                "Event": "-",
                "Point of Interest List": [
                    "Sweet Bristol Bungalow, stay from 08:00 to 09:00, nearest transit: Salinas & Clifton, 819.76m away;" #city 3 hotel
                    " Blackbird Bakery, visit from 09:00 to 10:00, nearest transit: Cumberland St & Waters Alley, 84.53m away;"
                    " Cycle the City, visit from 10:00 to 13:00, nearest transit: Home Depot, 6254128.85m away;"
                    " Three Brothers Burgers, visit from 13:00 to 15:00, nearest transit: Home Depot, 6254486.64m away;"
                    " Brunel's SS Great Britain, visit from 15:00 to 18:00, nearest transit: Home Depot, 6253545.34m away;"
                    " Cabot Tower, visit from 18:00 to 20:00, nearest transit: Home Depot, 6253464.57m away;"
                    " Miller & Carter, visit from 20:00 to 22:00, nearest transit: Home Depot, 6254038.48m away;"
                    " Sweet Bristol Bungalow, stay from 22:30 to 09:00, nearest transit: Salinas & Clifton, 819.76m away." #city 2 hotel
                ]
            },
            "Day 5": {
                "Current City": "from Bristol to Memphis", #travel 2nd_dest_city to 3rd_dest_city
                "Transportation": "Self-driving, Duration: 552.7683333333333 mins, Distance: 810.1358 km, Estimated Cost: $40.51", # remarks: not feasible to drive back from Santa Barbara to New York 
                "Breakfast": "", #skipped breakfast
                "Attraction": "Stax Museum of American Soul Music, Memphis; Main Street Trolley",
                "Lunch": "Kooky Canuck, Memphis",
                "Dinner": "Payne's Bar-B-Quea, Memphis",
                "Accommodation": "Sunny Bedroom at the Greenhouse Oasis, Memphis",
                "Event": "-",
                "Point of Interest List": [
                    "Sweet Bristol Bungalow, stay from 08:00 to 09:00, nearest transit: Salinas & Clifton, 819.76m away;" #city 2 hotel
                    " Rum Boogie Cafe, visit from 09:00 to 10:00, nearest transit: THIRD@PEABODYPL55, 30m away;"
                    " Bristol Museum & Art Gallery, visit from 11:00 to 12:30, nearest transit: Home Depot, 6253515.21m away;"
                    #leaved fro 3rd_dest_city i.e Nashville
                    " Sunny Bedroom at the Greenhouse Oasis, stay from 13:00 to 13:30, nearest trasnit: COOPER@OLIVER AVE, 365.35m away;" # city 3 hotel
                    " Kooky Canuck, visit from 13:30 to 15:00, nearest transit: UNION-MAIN/TRO NB, 116.26m away;"
                    " Stax Museum of American Soul Music, visit from 15:00 to 17:00, nearest transit: MCLEMORE@COLLEGE, 36.06m away;"
                    " Main Street Trolley, visit from 17:00 to 19:30, nearest transit: WHTC@MAIN, 216.39m away;"
                    " Payne's Bar-B-Que, visit from 19:30 to 21:00, nearest transit: LAMAR AVE@SEATTLE, 20.86m away;"
                    " Sunny Bedroom at the Greenhouse Oasis, stay from 22:00 to 08:30, nearest trasnit: COOPER@OLIVER AVE, 365.35m away;" #city 3 hotel

                    
                ]
            },
        "Day 6": {
                "Current City": "Memphis", #now in 2nd_dest city
                "Transportation": "-",
                "Breakfast": "Rum Boogie Cafe", #American
                "Attraction": "Graceland, Memphis; Backbeat Tours, Memphis",
                "Lunch": "Memphis BBQ Grill, Memphis",
                "Dinner": "Corky's Ribs & BBQ, Memphis",
                "Accommodation": "Modern Midtown Pad (Queen real bed), Memphis",
                "Event": "Sunny Bedroom at the Greenhouse Oasis, Memphis",
                "Point of Interest List": [
                    "Sunny Bedroom at the Greenhouse Oasis, stay from 08:30 to 09:30, nearest trasnit: COOPER@OLIVER AVE, 365.35m away;" #1st  city hotel
                    " Rum Boogie Cafe, visit from 09:30 to 11:00, nearest transit: THIRD@PEABODYPL55, 30m away;"
                    " Graceland, visit from 11:00 to 13:30, nearest trasnit: ELVIS PRESLEY BLVD@DOLAN DR, 199.90m away;"
                    " Memphis BBQ Grill, visit from 13:30 to 15:00, nearest transit: BERRYHILL@STAGE, 9810764.39m away;"
                    " Backbeat Tours, visit from 15:00 to 18:30, nearest transit: THIRD@PEABODYPL, 78.56m away;"
                    " Corky's Ribs & BBQ, visit from 20:30 to 22:00, nearest transit: POPLAR@PELHAM DR, 43.73m away;"
                    " Sunny Bedroom at the Greenhouse Oasis, stay from 23:30 to 09:00, nearest transit: COOPER@OLIVER AVE, 365.35m away." #city 3 hotel
                ]
            },
        "Day 7": {
                "Current City": "from Memphis to Raleigh", #from 3rd_dest_city to origin_city
                "Transportation": "Self-driving, Duration: 844.8666666666667 mins, Distance: 1213.1101999999998 km, Estimated Cost: $60.66", # remarks:  feasible to drive 
                "Breakfast": "Gus's World Famous Fried Chicken, Memphis",
                "Attraction": "The Peabody Ducks, Memphis",
                "Lunch": "Huey's Downtown, Memphis",
                "Dinner": "-",
                "Accommodation": "Sunny Bedroom at the Greenhouse Oasis, Memphis",
                "Event": "-",
                "Point of Interest List": [
                    "Sunny Bedroom at the Greenhouse Oasis, stay from 08:30 to 09:30, nearest trasnit: COOPER@OLIVER AVE, 365.35m away;" #city 3 hotel
                    " Gus's World Famous Fried Chicken, visit from 10:00 to 11:30, nearest transit: POPLAR@MENDENHALL, 189.63m away"
                    " The Peabody Ducks, visit from 11:30 to 13:00, nearest transit: UNION AVE @ S 3RD ST, 50.00m away;"
                    " Huey's Downtown, visit from 13:00 to 15:30, nearest transit: UNION-MAIN/TRO NB, 95.92m away."
                ]
        
    }

        
              

        
        # Add remaining days as needed
    }

    # Print the travel plan
    print("\nAnnotated Travel Plan:")
    for day, details in travel_plan.items():
        print(f"\n{day}:")
        for key, value in details.items():
            if isinstance(value, list):
                print(f"{key}:")
                for item in value:
                    print(f"  {item}")
            else:
                print(f"{key}: {value}")

except KeyError:
    print("Column 'reference_information' does not exist in the file.")
except IndexError:
    print(f"Row {row_number} does not exist in the file.")
except json.JSONDecodeError as e:
    print(f"JSON decoding error for row {row_number}: {e}")
# Out:
# Row 78 - Keys and Content in 'reference_information_1':
#
# Entry 1:
#   Description: Attractions in Memphis
#   Content: name subcategories visit_duration address latitude longitude website
# AutoZone Park ['Sights & Landmarks'] 3.0 Union Ave and Third Ave, Memphis, TN 38103 35.142677 -90.049995 https://www.milb.com/memphis/ballpark/autozone-park
# Memphis City Tour with Optional Riverboat Cruise & Sun Studio Add-On Options []  Memphis, TN
# Main Street Trolley ['Tours', 'Transportation'] 2.25 Main St and Riverfront, Memphis, TN 38103 35.15905 -90.04797 http://www.matatransit.com/services/trolleys/
# Memphis Riverboats ['Tours', 'Boat Tours & Water Sports', 'Outdoor Activities'] 3.5 45 S Riverside Dr Beale Street Landing, Memphis, TN 38103-2421 35.144867 -90.05629 http://www.memphisriverboats.net/
# Backbeat Tours ['Tours', 'Outdoor Activities'] 3.5 197 Beale St on the patio at Alfred's on Beale, Memphis, TN 38103-3128 35.139446 -90.051735 http://www.backbeattours.com/
# ...

# %% [markdown]
# # Row 82 Traveler Type: Laidback Traveler; Purpose of Travel: Cultural Exploration; Spending Preference: Luxury Traveler; Location Preference: Mountains

# %%
import pandas as pd
import json

# Load the CSV file
file_path = "final_7day_dataset.csv" #"modified_sample_54_UHRS_with_persona.csv"  # Update with the correct path if needed
df = pd.read_csv(file_path)

# Hardcoded row number (0-indexed)
row_number = 80  # Change this to the desired row number. For query in row X, make row_number = X-2

# Extract the reference_information column for the specified row
try:
    reference_data_1 = df.loc[row_number, "reference_information_1"]
    reference_data_2 = df.loc[row_number, "reference_information_2"]
    reference_data_3 = df.loc[row_number, "reference_information_3"]
    
    # Parse the JSON string into a Python object (list of dictionaries)
    parsed_data = json.loads(reference_data_1)
    parsed_data_2 = json.loads(reference_data_2)
    parsed_data_3 = json.loads(reference_data_3)
    
    # Ensure the data is a list of dictionaries
    if isinstance(parsed_data, list) and all(isinstance(d, dict) for d in parsed_data):
        print(f"Row {row_number+2} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

    if isinstance(parsed_data_2, list) and all(isinstance(d, dict) for d in parsed_data_2):
        # print(f"Row {row_number} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 9}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

    if isinstance(parsed_data_3, list) and all(isinstance(d, dict) for d in parsed_data_3):
        # print(f"Row {row_number} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data_3):
            print(f"\nEntry {idx + 15}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

except KeyError:
    print("Column 'reference_information' does not exist in the file.")
except IndexError:
    print(f"Row {row_number} does not exist in the file.")
except json.JSONDecodeError:
    print(f"Row {row_number} - 'reference_information' column is not a valid JSON string.")
# Out:
# Row 82 - Keys and Content in 'reference_information':
#
# Entry 1:
#   Description: Attractions in Greensboro
#   Content: name subcategories visit_duration address latitude longitude website
# Antique Market Place ['Shopping'] 1.5 6428 Burnt Poplar Rd, Greensboro, NC 27409-9712 36.078262 -79.94932 http://www.triadantiques.com/
# Blandwood ['Sights & Landmarks'] 3.0 447 W Washington St, Greensboro, NC 27401-2348 36.06983 -79.79572 http://www.blandwood.org/
# Greensboro Coliseum Complex ['Sights & Landmarks'] 3.0 1921 W. Gate City Blvd., Greensboro, NC 27403 36.059658 -79.82573 http://www.greensborocoliseum.com/
# Lake Brandt Marina ['Nature & Parks', 'Outdoor Activities'] 4.25 5945 Lake Brandt Rd, Greensboro, NC 27455-8239 36.168797 -79.83696 http://www.greensboro-nc.gov/index.aspx?page=1317
# Gateway Gardens ['Nature & Parks'] 4.5 2924 E. Lee Street, Greensboro, NC 27406 36.055546 -79.745476 http://greensborobeautiful.org/gardens/gateway_gardens.php
# ...

# %%
import pandas as pd
import json

# Load the CSV file
file_path = "final_7day_dataset.csv"  # Update with the correct path if needed
df = pd.read_csv(file_path)

# Hardcoded row number (0-indexed)
row_number = 80  # Change this to the desired row number 79 here

# Extract the reference_information columns for the specified row
try:
    reference_data_1 = df.loc[row_number, "reference_information_1"]
    reference_data_2 = df.loc[row_number, "reference_information_2"]
    reference_data_3 = df.loc[row_number, "reference_information_3"]

    # Parse the JSON strings into Python objects (list of dictionaries)
    parsed_data = json.loads(reference_data_1)
    parsed_data_2 = json.loads(reference_data_2)
    parsed_data_3 = json.loads(reference_data_3)

    # Ensure the data is a list of dictionaries
    if isinstance(parsed_data, list) and all(isinstance(d, dict) for d in parsed_data):
        print(f"Row {row_number} - Keys and Content in 'reference_information_1':")
        for idx, dictionary in enumerate(parsed_data):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_1' is not a list of dictionaries.")

    if isinstance(parsed_data_2, list) and all(isinstance(d, dict) for d in parsed_data_2):
        print(f"\nRow {row_number} - Keys and Content in 'reference_information_2':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_2' is not a list of dictionaries.")

    if isinstance(parsed_data_3, list) and all(isinstance(d, dict) for d in parsed_data_2):
        print(f"\nRow {row_number} - Keys and Content in 'reference_information_3':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_3' is not a list of dictionaries.")    

    # Create the annotated travel plan with the adjusted format
    travel_plan = {
        "Day 1": {
            "Current City": "from Houston to Greensboro",
            "Transportation": "Self-driving, Duration: 1251.77 mins, Distance: 1808.7797 km, Estimated Cost: $90.44",
            "Breakfast": "Chez Genese, Greensboro", #skipped
            "Attraction": "Greensboro History Museum, Greensboro; Tanger Family Bicentennial Garden, Greensboro; Greensboro Science Center, Greensboro", # attraction in 1st destination city
            "Lunch": "Fleming's Prime Steakhouse & Wine Bar, Greensboro", #lunch in 2nd destination city, mostly skipped due to travelling from dest_1 to dest_2
            "Dinner": "Mythos Grill, Greensboro", #lunch in 2nd dest city
            "Accommodation": "Cottage at Three Magnolias, Greensboro", #accomodation in 2 destination city 
            "Event": "-",
            "Point of Interest List": [
                " Cottage at Three Magnolias, stay from 08:00 to 09:00, nearest transit: Battleground/Bessemer Ave (OB), 702.72m away;"
                " Chez Genese, visit from 09:00 to 10:30, nearest transit: Elm/Lewis, 86.23m away;"
                " Greensboro History Museum, visit from 10:30 to 12:00, nearest transit: Church/Lindsay, 131.50m away;"
                " Fleming's Prime Steakhouse & Wine Bar, visit from 12:30 to 13:30, nearest transit: West Friendly/Hobbs Road (OB), 99.18m away;"
                " Tanger Family Bicentennial Garden, visit from 14:00 to 16:00, nearest transit: West Friendly/Hobbs, 685.91m away;"
                " Greensboro Science Center, visit from 16:00 to 19:30, nearest transit: Lawndale/Natural Science Center, 145.66m away"
                " Mythos Grill, visit from 20:00 to 21:00, nearest transit: West Market/Walker, 60.36m away;"
                " Cottage at Three Magnolias, stay from 23:00 to 09:00, nearest transit: Battleground/Bessemer Ave (OB), 702.72m away."
            ]
        },
        # Add remaining days as needed
        "Day 2": {
                "Current City": "Greensboro", #now in 2nd_dest city
                "Transportation": "-", #no travel today 
                "Breakfast" : "Mimi's Cafe, Greensboro",
                "Attraction": "LeBauer Park, Greensboro; First National Bank Field, Greensboro; Ambleside Gallery, Greensboro",
                "Lunch": "Dames Chicken & Waffles, Greensboro",
                "Dinner": "Vito's Italian Restaurant, Greensboro",
                "Accommodation": "Cottage at Three Magnolias, Greensboro",
                "Event": "-",
                "Point of Interest List": [
                    
                    " Cottage at Three Magnolias, stay from 09:00 to 10:00, nearest transit: Battleground/Bessemer Ave (OB), 702.72m away;"
                    " Mimi's Cafe, visit from 10:00 to 11:30, nearest transit: West Friendly/Mimi's Restaurant, 40.77m away;"
                    " LeBauer Park, visit from 11:30 to 13:00, nearest transit: Elm/Friendly (Northbound), 147.15m away;"
                    " Dames Chicken & Waffles, visit from 13:00 to 15:00, nearest transit: Gorrell/MLK, 24.89m away;"
                    " First National Bank Field, visit from 15:00 to 18:00, nearest trasnit: 201 North Eugene St/Sandhill Center, 137.66m away;"
                    " Ambleside Gallery, visit from 18:00 to 20:00, nearest transit: Elm/Lewis, 35.43m away;"
                    " Vito's Italian Restaurant, visit from 20:00 to 22:00, nearest transit: Church St/Hall Towers, 149.43m away;"
                    " Cottage at Three Magnolias, stay from 23:00 to 09:00, nearest transit: Battleground/Bessemer Ave (OB), 702.72m away." #1st city hotel
                    
                ]
            },
            "Day 3": {
                "Current City": "from Greensboro to Wilmington", #travel from 1st_dest_city to 2nd_dest_city
                "Transportation": "Self-driving, Duration: 238.51333333333332 mins, Distance: 334.28679999999997 km, Estimated Cost: $16.71", #we'll self deive from san luis obispo to san barbara 
                "Breakfast": "Golden Wok, Greensboro", #skipped breakfast
                "Attraction": "Noni Bacca Winery, Wilmington; Downtown Wilmington, Wilmington; ",
                "Lunch": "-", #skipped
                "Dinner": "Iron Hill Brewery & Restaurant, Greensboro",
                "Accommodation": "The Zen Den, Greensboro",
                "Event": "-",
                "Point of Interest List": [
                    " Cottage at Three Magnolias, stay from 09:00 to 10:00, nearest transit: Battleground/Bessemer Ave (OB), 702.72m away;"
                    " Golden Wok, visit from 10:00 to 11:30, nearest transit: Sapp Rd/Wendover Place, 252.80m away;"
                    #leaved from 3rd_dest_city
                    " The Zen Den, stay from 14:30 to 15:00, nearest transit: Bath Market St WB at 12th St, 326.90m away;" # city 3 hotel
                    " Noni Bacca Winery, visit from 15:00 to 17:30, nearest transnit: Racine Dr NB at Liberty Commons, 233.88m away;"
                    " Downtown Wilmington, visit from 18:00 to 19:30, nearest transit: Front St SB at Chestnut St, 66.26m away;"
                    " Iron Hill Brewery & Restaurant, visit from 20:00 to 22:00, nearest transit: Gordon Rd WB at Military Cutoff Rd, 639822.86m away;"
                    " The Zen Den, stay from 22:30 to 08:00, nearest transit: Bath Market St WB at 12th St, 326.90m away." #city 2 hotel
                    
                ]
            },
            "Day 4": {
                "Current City": "Wilmington", #now explore dest_city_3
                "Transportation": "-", #no travel today 
                "Breakfast" : "Kilwins Ice Cream -  Chocolate - Fudge",
                "Attraction": "Poplar Grove Plantation, Wilmington; Battleship North Carolina, Wilmington; Burgwin-Wright House and Gardens, Wilmington",
                "Lunch": "The Peppered Cupcake, Wilmington",
                "Dinner": "Fish Bites Seafood, Wilmington",
                "Accommodation": "The Zen Den, Wilmington",
                "Event": "-",
                "Point of Interest List": [
                    " The Zen Den, stay from 08:00 to 09:00, nearest transit: Bath Market St WB at 12th St, 326.90m away;" # city 3 hotel
                    " Kilwins Ice Cream -  Chocolate - Fudge, visit from 09:00 to 10:00, nearest transit: Front St SB at Market St, 48.84m away;"
                    " Poplar Grove Plantation, visit from 10:00 to 12:00, nearest transit: Gordon Rd WB at Military Cutoff Rd, 8613.40m away;"
                    " Battleship North Carolina, visit from 12:00 to 14:00, nearest transit: Front St SB at Chestnut St, 454.38m away;"
                    " The Peppered Cupcake, visit from 14:00 to 15:30, nearest transit: Front St SB at Orange St, 107.21m away;"
                    " Burgwin-Wright House and Gardens, visit from 16:00 to 19:00, nearest transit: 3rd St SB at Dock St, 75.52m away;"
                    " Fish Bites Seafood, visit from 20:00 to 21:30, nearest transit: Carolina Beach Rd NB at College Rd, 2839.13m away;"
                    " The Zen Den, stay from 22:30 to 08:00, nearest transit: Bath Market St WB at 12th St, 326.90m away."
                     
                ]
            },
            "Day 5": {
                "Current City": "from Wilmington to Charlotte", #travel 2nd_dest_city to 3rd_dest_city
                "Transportation": "Flight Number: F2615012, from Wilmington to Charlotte, Departure Time: 11:49, Arrival Time: 12:53", # remarks: not feasible to drive back from Santa Barbara to New York 
                "Breakfast": "Flaming Amy's Burrito Barn, Wilmington", #
                "Attraction": "Sullenberger Aviation Museum, Charlotte; Charlotte Premium Outlets, Charlotte",
                "Lunch": "Mert's Heart and Soul, Charlotte",
                "Dinner": "The Capital Grille, Charlotte",
                "Accommodation": "Quiet Cozy Stay in CLT, Charlotte",
                "Event": "-",
                "Point of Interest List": [
                    "The Zen Den, stay from 08:00 to 09:00, nearest transit: Bath Market St WB at 12th St, 326.90m away;"
                    " Flaming Amy's Burrito Barn, visit from 09:00 to 10:00, nearest transit: Oleander Dr EB at Audubon Blvd, 106.71m away;"
                    #leaved fro 3rd_dest_city i.e Nashville
                    " Quiet Cozy Stay in CLT, stay from 13:00 to 14:00, nearest transit: Tryon St & Choate Rd, 121.01m away;" #city 3 hotel
                    " Mert's Heart and Soul, visit from 14:00 to 15:30, nearest transit: College St & 6th St, 64.34m away;"
                    " Sullenberger Aviation Museum, visit from 16:00 to 19:00, nearest transit: Charlotte Douglas Airport, 956.40m away;"
                    " Charlotte Premium Outlets, visit from 19:00 to 21:00, nearest transit: Dixie River Rd & New Fashion Rd, 276.40m away;"
                    " The Capital Grille, visit from 21:00 to 23:00, nearest transit: Tryon St & 6th St, 103.97m away;"
                    " Quiet Cozy Stay in CLT, stay from 23:00 to 08:00, nearest transit: Tryon St & Choate Rd, 121.01m away."

                    
                ]
            },
        "Day 6": {
                "Current City": "Charlotte", #now in 2nd_dest city
                "Transportation": "-",
                "Breakfast": "Charlotte's Coffee House, Charlotte", #American
                "Attraction": "Romare Bearden Park, Charlotte; Fourth Ward, Charlotte; Belk Theater at Blumenthal Performing Arts Center, Charlotte",
                "Lunch": "Charlotte Quay Restaurant, Charlotte",
                "Dinner": "Mac's Speed Shop, Charlotte",
                "Accommodation": "Quiet Cozy Stay in CLT, Charlotte",
                "Event": "-",
                "Point of Interest List": [
                    " Quiet Cozy Stay in CLT, stay from 08:00 to 09:00, nearest transit: Tryon St & Choate Rd, 121.01m away;" #1st  city hotel
                    " Charlotte's Coffee House, stay from 09:00 to 10:00, nearest transit: Oakland St & Main Ave, 1148929.15m away;"
                    " Romare Bearden Park, visit from 10:00 to 12:00, nearest transit: Church St & 3rd St, 165.91m away;"
                    " Fourth Ward, visit from 12:00 to 14:00, nearest transit: Church St & 6th St, 129.82m away;"
                    " Charlotte Quay Restaurant, visit from 14:00 to 16:00, nearest transit: Beaty St @ 866, 5961834.13m away;"
                    " Belk Theater at Blumenthal Performing Arts Center, visit from 16:00 to 20:30, nearest transit: Trade St & College St, 118.24m away;"
                    " Mac's Speed Shop, visit from 21:00  to 22:30, nearest transit: New Bern Station, 544.51m away;"
                    " Quiet Cozy Stay in CLT, stay from 23:00 to 09:00, nearest transit: Tryon St & Choate Rd, 121.01m away." #city 3 hotel
                ]
            },
        "Day 7": {
                "Current City": "from Charlotte to Houston", #from 3rd_dest_city to origin_city
                "Transportation": "Flight Number: F1220099, flight from Charlotte to Houston, Departure Time: 18:56, Arrival Time: 20:22", # remarks:  feasible to drive 
                "Breakfast": "Charlotte's Eats and Sweets, Charlotte",
                "Attraction": "Truist Field, Charlotte; ",
                "Lunch": "Midwood Smokehouse, Charlotte",
                "Dinner": "-",
                "Accommodation": "Quiet Cozy Stay in CLT, Charlotte",
                "Event": "-",
                "Point of Interest List": [
                    "Quiet Cozy Stay in CLT, stay from 09:00 to 10:00, nearest transit: Tryon St & Choate Rd, 121.01m away;" #city 3 hotel
                    " Charlotte's Eats and Sweets, visit from 10:00 to 11:30, nearest transit: Oakland St & Main Ave, 991745.06m away;"
                    " Truist Field, visit from 12:00 to 14:00, nearest transit: 4th St & Graham St, 146.25m away;"
                    " Midwood Smokehouse, visit from 14:00 to 16:00, nearest transit: Central Ave & Clement Ave, 40.68m away."
                ]
        
    }

        
              

        
        # Add remaining days as needed
    }

    # Print the travel plan
    print("\nAnnotated Travel Plan:")
    for day, details in travel_plan.items():
        print(f"\n{day}:")
        for key, value in details.items():
            if isinstance(value, list):
                print(f"{key}:")
                for item in value:
                    print(f"  {item}")
            else:
                print(f"{key}: {value}")

except KeyError:
    print("Column 'reference_information' does not exist in the file.")
except IndexError:
    print(f"Row {row_number} does not exist in the file.")
except json.JSONDecodeError as e:
    print(f"JSON decoding error for row {row_number}: {e}")
# Out:
# Row 80 - Keys and Content in 'reference_information_1':
#
# Entry 1:
#   Description: Attractions in Greensboro
#   Content: name subcategories visit_duration address latitude longitude website
# Antique Market Place ['Shopping'] 1.5 6428 Burnt Poplar Rd, Greensboro, NC 27409-9712 36.078262 -79.94932 http://www.triadantiques.com/
# Blandwood ['Sights & Landmarks'] 3.0 447 W Washington St, Greensboro, NC 27401-2348 36.06983 -79.79572 http://www.blandwood.org/
# Greensboro Coliseum Complex ['Sights & Landmarks'] 3.0 1921 W. Gate City Blvd., Greensboro, NC 27403 36.059658 -79.82573 http://www.greensborocoliseum.com/
# Lake Brandt Marina ['Nature & Parks', 'Outdoor Activities'] 4.25 5945 Lake Brandt Rd, Greensboro, NC 27455-8239 36.168797 -79.83696 http://www.greensboro-nc.gov/index.aspx?page=1317
# Gateway Gardens ['Nature & Parks'] 4.5 2924 E. Lee Street, Greensboro, NC 27406 36.055546 -79.745476 http://greensborobeautiful.org/gardens/gateway_gardens.php
# ...

# %%
#  Row 83 Traveler Type: Laidback Traveler; Purpose of Travel: Relaxation; Spending Preference: Economical Traveler; Location Preference: Mountains

import pandas as pd
import json

# Load the CSV file
file_path = "final_7day_dataset.csv" #"modified_sample_54_UHRS_with_persona.csv"  # Update with the correct path if needed
df = pd.read_csv(file_path)

# Hardcoded row number (0-indexed)
row_number = 81  # Change this to the desired row number. For query in row X, make row_number = X-2

# Extract the reference_information column for the specified row
try:
    reference_data_1 = df.loc[row_number, "reference_information_1"]
    reference_data_2 = df.loc[row_number, "reference_information_2"]
    reference_data_3 = df.loc[row_number, "reference_information_3"]
    
    # Parse the JSON string into a Python object (list of dictionaries)
    parsed_data = json.loads(reference_data_1)
    parsed_data_2 = json.loads(reference_data_2)
    parsed_data_3 = json.loads(reference_data_3)
    
    # Ensure the data is a list of dictionaries
    if isinstance(parsed_data, list) and all(isinstance(d, dict) for d in parsed_data):
        print(f"Row {row_number+2} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

    if isinstance(parsed_data_2, list) and all(isinstance(d, dict) for d in parsed_data_2):
        # print(f"Row {row_number} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 9}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

    if isinstance(parsed_data_3, list) and all(isinstance(d, dict) for d in parsed_data_3):
        # print(f"Row {row_number} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data_3):
            print(f"\nEntry {idx + 15}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

except KeyError:
    print("Column 'reference_information' does not exist in the file.")
except IndexError:
    print(f"Row {row_number} does not exist in the file.")
except json.JSONDecodeError:
    print(f"Row {row_number} - 'reference_information' column is not a valid JSON string.")

import pandas as pd
import json

# Load the CSV file
file_path = "final_7day_dataset.csv"  # Update with the correct path if needed
df = pd.read_csv(file_path)

# Hardcoded row number (0-indexed)
row_number = 81# Change this to the desired row number 83 here

# Extract the reference_information columns for the specified row
try:
    reference_data_1 = df.loc[row_number, "reference_information_1"]
    reference_data_2 = df.loc[row_number, "reference_information_2"]
    reference_data_3 = df.loc[row_number, "reference_information_3"]

    # Parse the JSON strings into Python objects (list of dictionaries)
    parsed_data = json.loads(reference_data_1)
    parsed_data_2 = json.loads(reference_data_2)
    parsed_data_3 = json.loads(reference_data_3)

    # Ensure the data is a list of dictionaries
    if isinstance(parsed_data, list) and all(isinstance(d, dict) for d in parsed_data):
        print(f"Row {row_number} - Keys and Content in 'reference_information_1':")
        for idx, dictionary in enumerate(parsed_data):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_1' is not a list of dictionaries.")

    if isinstance(parsed_data_2, list) and all(isinstance(d, dict) for d in parsed_data_2):
        print(f"\nRow {row_number} - Keys and Content in 'reference_information_2':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_2' is not a list of dictionaries.")

    if isinstance(parsed_data_3, list) and all(isinstance(d, dict) for d in parsed_data_2):
        print(f"\nRow {row_number} - Keys and Content in 'reference_information_3':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_3' is not a list of dictionaries.")    

    # Create the annotated travel plan with the adjusted format
    travel_plan = {
        "Day 1": {
            "Current City": "from Nashville to San Diego",
            "Transportation": "Flight Number: F3087881, from Nashville to San Diego, Departure Time: 09:43, Arrival Time: 11:58",
            "Breakfast": "-", #skipped
            "Attraction": "La Jolla Cove, San Diego; Petco Park, San Diego", # attraction in 1st destination city
            "Lunch": "Ironside Fish & Oyster, San Diego", #lunch in 2nd destination city, mostly skipped due to travelling from dest_1 to dest_2
            "Dinner": "Trailer Park After Dark, San Diego", #lunch in 2nd dest city
            "Accommodation": "Twin Bed, San Diego", #accomodation in 2 destination city 
            "Event": "-",
            "Point of Interest List": [
                " Twin Bed, stay from 12:00 to 13:00, nearest transit: Clairemont Mesa Bl & Limerick Av, 270.85m away;"
                " Ironside Fish & Oyster, visit from 13:00 to 15:00, nearest transit: India St & Cedar St, 57.08m away;"
                " La Jolla Cove, visit from 15:00 to 17:00, nearest transit: Silverado St & Herschel Av, 578.68m away;"
                " Petco Park, visit from 17:00 to 20:30, nearest transit: 10th Av & Park Bl (Petco Park), 185.00m away;"
                " Trailer Park After Dark, visit from 21:00 to 22:30, nearest transit: Broadway & 6th Av, 164.41m away;"
                " Twin Bed, stay from 22:30 to 08:00, nearest transit: Clairemont Mesa Bl & Limerick Av, 270.85m away."
            ]
        },
        
        "Day 2": {
                "Current City": "San Diego", #now in 2nd_dest city
                "Transportation": "-", #no travel today 
                "Breakfast" : "Alforon, San Diego",
                "Attraction": " Mt. Soledad National Veterans Memorial, San Diego; Coronado Bridge, San Diego; Little Italy, San Diego",
                "Lunch": " Vessel Restaurant + Bar, San Diego",
                "Dinner": " Dockside 1953, San Diego",
                "Accommodation": "Twin Bed, San Diego",
                "Event": "-",
                "Point of Interest List": [
                    " Twin Bed, stay from 08:00 to 09:00, nearest transit: Clairemont Mesa Bl & Limerick Av, 270.85m away;"
                    " Alforon, visit from 09:00 to 10:00, nearest transit: El Cajon Bl & 59th St, 121.18m away;"
                    " Mt. Soledad National Veterans Memorial, visit from 10:00 to 13:00, nearest transit: Torrey Pines Rd & Calle De La Plata, 1714.29m away;"
                    " Vessel Restaurant + Bar, visit from 13:00 to 15:00, nearest transit: Rosecrans St & McCall St, 576.30m away;"
                    " Coronado Bridge, visit from 15:00 to 17:00, nearest transit: Barrio Logan Station, 1138.11m away;"
                    " Little Italy, visit from 17:00 to 20:00, visit from: Kettner Bl & Grape St, 155.04m away;"
                    " Dockside 1953, visit from 20:00 to 22:00, nearest transit: W Mission Bay Dr & Gleason Rd, 127.87m away;"
                    " Twin Bed, stay from 22:30 to 08:00, nearest transit: Clairemont Mesa Bl & Limerick Av, 270.85m away."
                    
                   
                    
                ]
            },
            "Day 3": {
                "Current City": "from San Diego to San Francisco", #travel from 1st_dest_city to 2nd_dest_city
                "Transportation": "Flight Number: F0449913, from San Diego to San Francisco, Departure Time: 14:40, Arrival Time: 16:07", #we'll self deive from san luis obispo to san barbara 
                "Breakfast": "Din Tai Fung, San Diego", #skipped breakfast
                "Attraction": "Birch Aquarium at Scripps, San Diego; ",
                "Lunch": "-", #skipped
                "Dinner": "Scala's Bistro, San Francisco",
                "Accommodation": "Modern Single Studio, San Francisco",
                "Event": "-",
                "Point of Interest List": [
                    " Twin Bed, stay from 08:00 to 10:00, nearest transit: Clairemont Mesa Bl & Limerick Av, 270.85m away;"
                    " Din Tai Fung, visit from 10:00 to 11:30, nearest transit: La Jolla Village Dr & Genesee Av, 68.36m away;"
                    " Birch Aquarium at Scripps, visitt from 11:30 to 13:00, nearest transit: La Jolla Shores Dr & Scripps Institute, 135.62m away;"
                    #leaved from 3rd_dest_city
                    " Modern Single Studio, visit from 16:10 to 17:00, nearest transit: Civic Center @ 7th (Yotel), 1283.60m away;" # city 3 hotel
                    " Ferry Building Marketplace, visit from 17:00 to 20:00, nearest transit: Mission @ Spear (Embarcadero)334.47m away;"
                    " Scala's Bistro, visit from 20:00 to 22:00, nearest transit: Powell @ 22 4th, 451.00m away;"
                    " Modern Single Studio, visit from 23:00 to 08:00, nearest transit: Civic Center @ 7th (Yotel), 1283.60m away." #city 2 hotel
                    
                ]
            },
            "Day 4": {
                "Current City": "San Francisco", #now explore dest_city_3
                "Transportation": "-", #no travel today 
                "Breakfast" : "Eight Am, San Francisco",
                "Attraction": "Japanese Tea Garden, San Francisco; California Academy of Sciences Civic Center, San Francisco; Golden Gate Bridge, San Francisco",
                "Lunch": "Crab House at Pier 39, San Francisco",
                "Dinner": "Mersea Restaurant & Bar, San Francisco",
                "Accommodation": "Modern Single Studio, San Francisco",
                "Event": "-",
                "Point of Interest List": [
                    " Modern Single Studio, visit from 08:00 to 10:00, nearest transit: Civic Center @ 7th (Yotel), 1283.60m away;" # city 3 hotel
                    " Eight Am, visit from 10:00 to 11:30, nearest transit: Powell @ 22 4th, 2606.31m away;"
                    " Japanese Tea Garden, visit from 11:30 to 13:00, nearest transit: Civic Center BART (9th and Market), 4861.86m away;"
                    " Crab House at Pier 39, visit from 13:00 to 15:00, nearest transit: Mission @ Spear (Embarcadero), 2366.47m away;"
                    " California Academy of Sciences Civic Center, visit from 15:00 to 18:00, nearest transit: BART (9th and Market), 4489.93m away;"
                    " Golden Gate Bridge, visit from 18:00 to 20:00, nearest transit: Civic Center BART (9th and Market), 7261.63m away;"
                    " Mersea Restaurant & Bar, visit from 20:30 to 22:00, nearest transit: Mission @ Spear (Embarcadero), 3667.91m away;"
                    " Modern Single Studio, visit from 23:00 to 08:00, nearest transit: Civic Center @ 7th (Yotel), 1283.60m away."
                    
                     
                ]
            },
            "Day 5": {
                "Current City": "from San Francisco to Los Angeles", #travel 2nd_dest_city to 3rd_dest_city
                "Transportation": "Flight Number: F0505952, from San Francisco to Los Angeles, Departure Time: 10:41, Arrival Time: 12:17", # remarks: not feasible to drive back from Santa Barbara to New York 
                "Breakfast": "Eagle Cafe, San Francisco", #
                "Attraction": "Los Angeles County Museum of Art, Los Angeles; The Grove, Los Angeles",
                "Lunch": "Bavel, Los Angeles",
                "Dinner": "25 Degrees",
                "Accommodation": "MidCity, Los Angeles",
                "Event": "-",
                "Point of Interest List": [
                    " Modern Single Studio, visit from 08:00 to 09:00, nearest transit: Civic Center @ 7th (Yotel), 1283.60m away;"
                    " Eagle Cafe, visit from 09:00 to 10:00, nearest transit: Mission @ Spear (Embarcadero), 2308.55m away;"
                    #leaved fro 3rd_dest_city i.e Los Angeles
                    " MidCity, stay from 12:20 to 13:00, nearest transit: Adams & Crenshaw Blvd. (Northbound), 359.70m away;"
                    " Bavel, visit from 13:00 to 15:00, nearest transit: Molino St & Palmetto St, 153.71m away;"
                    " Los Angeles County Museum of Art, visit from 15:00 to 17:00, nearest transit: Wilshire Blvd & Ogden (Westbound), 177.16m away;"
                    " The Grove, visit from 17:00 to 19:00, nearest transit:  3rd & Ogden (Eastbound), 143.67m away;"
                    " 25 Degrees, visit from 20:30 to 22:00, nearest transit: Highland & Hollywood Blvd., 295.86m away;"
                    
                    " MidCity, stay from 22:30 to 09:00, nearest transit: Adams & Crenshaw Blvd. (Northbound), 359.70m away."

                    
                ]
            },
        "Day 6": {
                "Current City": "Los Angeles", #now in 2nd_dest city
                "Transportation": "-",
                "Breakfast": "Olive & Thyme, Los Angeles", #American
                "Attraction": "Hollywood Sign, Los Angeles; Hollywood Walk of Fame, Los Angeles",
                "Lunch": "Leo & Lily, Los Angeles",
                "Dinner": "Park's BBQ, Los Angeles",
                "Accommodation": "MidCity, Los Angeles",
                "Event": "-",
                "Point of Interest List": [
                    " MidCity, stay from 09:00 to 10:00, nearest transit: Adams & Crenshaw Blvd. (Northbound), 359.70m away;"
                    " Olive & Thyme, visit from 10:00 to 11:00, nearest transit:  Alameda Ave & Pass Ave (Eastbound), 219.80m away;"
                    " Hollywood Sign, visit from 11:00 to 14:00, nearest transit:  Beachwood & Westshire, 1574.74m away;"
                    " Leo & Lily, visit from 14:00 to 16:00, nearest transit: Ventura Blvd & Shoup Ave (Eastbound), 52.03m away;"
                    " Hollywood Walk of Fame, visit from 16:00 to 19:00, nearest transit: Hollywood & Vine St., 17.12m away;"
                    " Park's BBQ, visit from 20:00 to 21:30, nearest transit: Vermont & Olympic Blvd. (CCW), 123.02m away;"
                    
                    " MidCity, stay from 22:00 to 09:00, nearest transit: Adams & Crenshaw Blvd. (Northbound), 359.70m away." #city 3 hotel
                ]
            },
        "Day 7": {
                "Current City": "from Los Angeles to Nashville", #from 3rd_dest_city to origin_city
                "Transportation": "Flight Number: F1935860, Departure Time: 13:29, Arrival Time: 19:20", # remarks:  feasible to drive 
                "Breakfast": " Cafe Gratitude Venice, Los Angeles", 
                "Attraction": "Griffith Observatory, Los Angeles; ",
                "Lunch": "",
                "Dinner": "-",
                "Accommodation": "MidCity, Los Angeles",
                "Event": "-",
                "Point of Interest List": [
                    " MidCity, stay from 09:00 to 10:00, nearest transit: Adams & Crenshaw Blvd. (Northbound), 359.70m away;"
                    " Cafe Gratitude Venice, visit from 10:00 to 11:30, nearest transit: Pacific Ave & Washington Blvd (Arriving), 2169.02m away;"
                    " Griffith Observatory, visit from: 11:30 to 13:00, nearest transit: Griffith Observatory, 90.42m away."
                ]
        
    }

        
              

        
        # Add remaining days as needed
    }

    # Print the travel plan
    print("\nAnnotated Travel Plan:")
    for day, details in travel_plan.items():
        print(f"\n{day}:")
        for key, value in details.items():
            if isinstance(value, list):
                print(f"{key}:")
                for item in value:
                    print(f"  {item}")
            else:
                print(f"{key}: {value}")

except KeyError:
    print("Column 'reference_information' does not exist in the file.")
except IndexError:
    print(f"Row {row_number} does not exist in the file.")
except json.JSONDecodeError as e:
    print(f"JSON decoding error for row {row_number}: {e}")
# Out:
# Row 83 - Keys and Content in 'reference_information':
#
# Entry 1:
#   Description: Attractions in San Diego
#   Content: name subcategories visit_duration address latitude longitude website
# Sunset Cliffs Natural Park ['Nature & Parks'] 4.5 Ladera St, San Diego, CA 92107-4015 32.715935 -117.25517 http://www.sandiego.gov/park-and-recreation/parks/regional/shoreline/sunset
# Cabrillo National Monument ['Sights & Landmarks', 'Nature & Parks'] 3.75 1800 Cabrillo Memorial Dr Point Loma Ecological Reserve, San Diego, CA 92106-3601 32.672264 -117.24161 http://www.nps.gov/cabr
# La Jolla Cove ['Nature & Parks', 'Outdoor Activities'] 4.25 1100 Coast Blvd, La Jolla, San Diego, CA 92037-3600 32.850586 -117.27309
# Balboa Park ['Fun & Games', 'Nature & Parks'] 3.0 1549 El Prado, San Diego, CA 92101-1660 32.731518 -117.15017 http://www.balboapark.org/
# ...

# %% [markdown]
# # Row 84 Traveler Type: Laidback Traveler; Purpose of Travel: Nature; Spending Preference: Economical Traveler; Location Preference: Mountains

# %%
import pandas as pd
import json

# Load the CSV file
file_path = "final_7day_dataset.csv" #"modified_sample_54_UHRS_with_persona.csv"  # Update with the correct path if needed
df = pd.read_csv(file_path)

# Hardcoded row number (0-indexed)
row_number = 82  # Change this to the desired row number. For query in row X, make row_number = X-2

# Extract the reference_information column for the specified row
try:
    reference_data_1 = df.loc[row_number, "reference_information_1"]
    reference_data_2 = df.loc[row_number, "reference_information_2"]
    reference_data_3 = df.loc[row_number, "reference_information_3"]
    
    # Parse the JSON string into a Python object (list of dictionaries)
    parsed_data = json.loads(reference_data_1)
    parsed_data_2 = json.loads(reference_data_2)
    parsed_data_3 = json.loads(reference_data_3)
    
    # Ensure the data is a list of dictionaries
    if isinstance(parsed_data, list) and all(isinstance(d, dict) for d in parsed_data):
        print(f"Row {row_number+2} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

    if isinstance(parsed_data_2, list) and all(isinstance(d, dict) for d in parsed_data_2):
        # print(f"Row {row_number} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 9}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

    if isinstance(parsed_data_3, list) and all(isinstance(d, dict) for d in parsed_data_3):
        # print(f"Row {row_number} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data_3):
            print(f"\nEntry {idx + 15}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

except KeyError:
    print("Column 'reference_information' does not exist in the file.")
except IndexError:
    print(f"Row {row_number} does not exist in the file.")
except json.JSONDecodeError:
    print(f"Row {row_number} - 'reference_information' column is not a valid JSON string.")
# Out:
# Row 84 - Keys and Content in 'reference_information':
#
# Entry 1:
#   Description: Attractions in Fort Dodge
#   Content: name subcategories visit_duration address latitude longitude website
# Studio Fusion ['Shopping', 'Classes & Workshops', 'Fun & Games'] 1.5 21 S 12th St, Fort Dodge, IA 50501-4831 42.505436 -94.18243 http://Studio-fusion.com
# Blanden Art Museum ['Shopping', 'Museums'] 2.25 920 3rd Ave S, Fort Dodge, IA 50501-4723 42.50268 -94.18453 http://www.blanden.org/
# Fort Dodge Grain Silo Mural ['Sights & Landmarks'] 3.0 727 Hawkeye Ave, Fort Dodge, IA 42.51165 -94.20238
# Fort Frenzy ['Fun & Games'] 1.5 3232 1st Ave South, Fort Dodge, IA 50501-6424 42.50547 -94.15039 http://www.fortfrenzy.com/home
# Community Orchard ['Sights & Landmarks'] 3.0 2237 160th St, Fort Dodge, IA 50501-8547 42.55984 -94.19987 http://www.communityorchard.com
# The Fort Museum & Frontier Village ['Museums'] 3.0 1 Museum Rd, Fort Dodge, IA 50501-6506 42.48753 -94.19891 http://www.fortmuseumfv.com
# ...

# %%
import pandas as pd
import json

# Load the CSV file
file_path = "final_7day_dataset.csv"  # Update with the correct path if needed
df = pd.read_csv(file_path)

# Hardcoded row number (0-indexed)
row_number = 82  # Change this to the desired row number 79 here

# Extract the reference_information columns for the specified row
try:
    reference_data_1 = df.loc[row_number, "reference_information_1"]
    reference_data_2 = df.loc[row_number, "reference_information_2"]
    reference_data_3 = df.loc[row_number, "reference_information_3"]

    # Parse the JSON strings into Python objects (list of dictionaries)
    parsed_data = json.loads(reference_data_1)
    parsed_data_2 = json.loads(reference_data_2)
    parsed_data_3 = json.loads(reference_data_3)

    # Ensure the data is a list of dictionaries
    if isinstance(parsed_data, list) and all(isinstance(d, dict) for d in parsed_data):
        print(f"Row {row_number} - Keys and Content in 'reference_information_1':")
        for idx, dictionary in enumerate(parsed_data):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_1' is not a list of dictionaries.")

    if isinstance(parsed_data_2, list) and all(isinstance(d, dict) for d in parsed_data_2):
        print(f"\nRow {row_number} - Keys and Content in 'reference_information_2':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_2' is not a list of dictionaries.")

    if isinstance(parsed_data_3, list) and all(isinstance(d, dict) for d in parsed_data_2):
        print(f"\nRow {row_number} - Keys and Content in 'reference_information_3':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_3' is not a list of dictionaries.")    

    # Create the annotated travel plan with the adjusted format
    travel_plan = {
        "Day 1": {
            "Current City": "from Atlanta to Fort Diego",
            "Transportation": "Self-driving, Duration: 1127.4983333333332 mins, Distance: 1596.4308999999998 km, Estimated Cost: $79.82",
            "Breakfast": "-", #skipped
            "Attraction": "Community Orchard, Fort Diego; Studio Fusion, Fort Diego", # attraction in 1st destination city
            "Lunch": "Dariette, Fort Diego", #lunch in 2nd destination city, mostly skipped due to travelling from dest_1 to dest_2
            "Dinner": "Rides Bar and Grill, Fort Diego", #lunch in 2nd dest city, 
            "Accommodation": "12 Private twin room, Fort Diego", #accomodation in 2 destination city 
            "Event": "-",
            "Point of Interest List": [
                " 12 Private twin room, stay from 11:30 to 12:30, nearest transit: cottage 5 Starlite 3369.38m away;"
                " Dariette, visit from 13:00 to 15:00, nearest transit: N 11th St and Central Ave, 88.99m away;"
                " Community Orchard, visit from 15:00 to 18:00, nearest transit: Village Green, 3093.21m away;"
                " Studio Fusion, visit from 18:00 to 21:00, nearest transit: N 11th St and Central Ave, 71.87m away;"
                " Rides Bar and Grill, visit from 21:00 to 23:00, nearest transit: S 31st St and 8th Ave S, 95.96m away;"
                
                " 12 Private twin room, stay from 23:00 to 08:30, nearest transit: cottage 5 Starlite 3369.38m away."
            ]
        },
        # Add remaining days as needed
        "Day 2": {
                "Current City": "Fort Diego", #now in 2nd_dest city
                "Transportation": "-", #no travel today 
                "Breakfast" : "Wendy's, Fort Diego",
                "Attraction": "Blanden Art Museum, Fort Diego;  Fort Frenzy, Fort Diego",
                "Lunch": "Pancheros Mexican Grill, Fort Diego",
                "Dinner": "Olde Boston's Restaurant & Pub, Fort Diego",
                "Accommodation": "12 Private twin room, Fort Diego",
                "Event": "-",
                "Point of Interest List": [
                    " 12 Private twin room, stay from 08:30 to 09:30, nearest transit: cottage 5 Starlite 3369.38m away;"
                    " Wendy's, visit from 09:30 to 11:00, nearest transit: S 25th St and 5th Ave S, 215.15m away;"
                    " Blanden Art Museum, visit from 11:00 to 14:00, nearest transit: 3rd Ave S and S 9th St, 75.70m away;"
                    " Pancheros Mexican Grill, visit from 14:00 to 15:30, nearest transit: Fort Dodge Kohl's, 178.26m away;"
                    " Fort Frenzy, visit from 16:00 to 19:30, nearest transit: 1st Ave S and S 31st St, 108.41m away;"
                    " Olde Boston's Restaurant & Pub, visit from 20:00 to 21:30, nearest transit: Trolley Center, 85.16m away;" 
                    " 12 Private twin room, stay from 11:30 to 12:30, nearest transit: cottage 5 Starlite 3369.38m away." #1st city hotel
                    
                ]
            },
            "Day 3": {
                "Current City": "from Fort Diego to Mason City", #travel from 1st_dest_city to 2nd_dest_city
                "Transportation": "Flight Number: F1168121,  from Fort Diego to Mason City, Departure Time: 09:03, Arrival Time: 09:49", #we'll self deive from san luis obispo to san barbara 
                "Breakfast": "-", #skipped breakfast
                "Attraction": "East Park, Mason City; Rock Crest - Rock Glen Historical District, Mason City; Stebens Theater, Mason City",
                "Lunch": "Birdsall's, Mason City", #skipped
                "Dinner": "",
                "Accommodation": "One Bedroom Lake Retreat, Mason City",
                "Event": "-",
                "Point of Interest List": [
                    " 12 Private twin room, stay from 08:30 to 09:00, nearest transit: cottage 5 Starlite 3369.38m away;"
                    
                    #leaved from 3rd_dest_city
                    " One Bedroom Lake Retreat, stay from 10:00 to 11:00, nearest transit: Best Buy, 12990.88m away;" #city 2 hotel
                    " East Park, visit from 11:00 to 13:00, nearest transit: E State St. and S Virginia Ave., 149.57m away"
                    " Birdsall's, visit from 13:00 to 15:00, nearest transit: Fareway, 155.13m away;"
                    " Rock Crest - Rock Glen Historical District, visit from 15:00 to 18:00, nearest transit: S Delaware Ave. and 2nd St. SW, 161.58m away;"
                    " Stebens Theater, visit from 18:00 to 21:00, nearest transit: N Pennsylvania Ave. and 6th St.,  183.51m away;"
                    " Thai Bistro, visit from 21:00 to 23:00, nearest transit: S Delaware Ave. and 2nd St. SW, 142.71m away;"


                    " One Bedroom Lake Retreat, stay from 23:00 to 09:00, nearest transit: Best Buy, 12990.88m away."
                    
                ]
            },
            "Day 4": {
                "Current City": "Mason City", #now explore dest_city_3
                "Transportation": "-", #no travel today 
                "Breakfast" : "Taco Tico, Mason City",
                "Attraction": "Trinity Lutheran Church, Mason City; Mason City Visitor Information Center, Mason City",
                "Lunch": "China Buffet, Mason City",
                "Dinner": "Prime N Wine, Mason City",
                "Accommodation": "One Bedroom Lake Retreat, Mason City",
                "Event": "-",
                "Point of Interest List": [
                    " One Bedroom Lake Retreat, stay from 09:00 to 10:00, nearest transit: Best Buy, 12990.88m away;"
                    " Taco Tico, visit from 10:00 to 11:30, nearest transit: Frontage Rd. SW and Briarstone Dr. (Perkins), 161.65m away;"
                    " Trinity Lutheran Church, visit from 11:30 t0 13:30, nearest transit: 3rd St. NE and N Pennsylvania Ave., 69.58m away;"
                    " China Buffet, visit from 14:00 to 16:00, nearest transit: S Taft Ave. and Frontage Rd. SW, 126.74m away;"
                    " Mason City Visitor Information Center, visit from 16:00 to 19:00, nearest transit: Frontage Rd. SW and Briarstone Dr. (Perkins), 126.98m away;"
                    " Prime N Wine, visit from 20:00 to 22:00, nearest transit: Frontage Rd. NW (McGregor Furniture), 128.03m away;"
                    " One Bedroom Lake Retreat, stay from 22:00 to 09:00, nearest transit: Best Buy, 12990.88m away."
                     
                ]
            },
            "Day 5": {
                "Current City": "from Mason City to Cedar Rapids", #travel 2nd_dest_city to 3rd_dest_city
                "Transportation": "Self-driving, Duration: 162.18833333333333 mins, Distance: 222.99820000000003 km, Estimated Cost: $11.15", # remarks: not feasible to drive back from Santa Barbara to New York 
                "Breakfast": "Mason's Root Beer Drive-In, Mason City", #
                "Attraction": "African American Museum of Iowa, Cedar Rapids; Masonic Library and Museum, Cedar Rapids",
                "Lunch": "-", #skipped
                "Dinner": "Los Compadres, Cedar Rapids",
                "Accommodation": "The Favorite Room at The Deer House-Room 1, Cedar Rapids",
                "Event": "-",
                "Point of Interest List": [
                    " One Bedroom Lake Retreat, stay from 09:00 to 10:00, nearest transit: Best Buy, 12990.88m away;"
                    " Mason's Root Beer Drive-In, visit from 10:00 to 11:30, nearest transit: North Iowa Area Community College, 709071.87m away;"
                    #leaved fro 3rd_dest_city i.e Cedar Rapids
                    " The Favorite Room at The Deer House-Room 1, stay from 14:00 to 15:00, nearest transit: 3rd Ave & 15th St, 108.77m away;"
                    " African American Museum of Iowa, visit from 15:00 to 18:00, nearest transit: 2nd St & 11th Ave, 194.44m away;"
                    " Masonic Library and Museum, visit from 18:00 to 20:30, nearest transit: 2nd Ave & 8th St, 93.95m away;"
                    " Los Compadres, visit from 20:30 to 22:00, nearest transit: 29th Ave & 6th St, 66.80m away;"
                    " The Favorite Room at The Deer House-Room 1, stay from 22:00 to 09:00, nearest transit: 3rd Ave & 15th St, 108.77m away."

                    
                ]
            },
        "Day 6": {
                "Current City": "Cedar Rapids", #now in 2nd_dest city
                "Transportation": "-",
                "Breakfast": "Lightworks Cafe, Cedar Rapids", #American
                "Attraction": "Mount Trashmore, Cedar Rapids; McGrath Amphitheatre, Cedar Rapids",
                "Lunch": "Need Pizzeria, Cedar Rapids",
                "Dinner": "Cheddar's Scratch Kitchen",
                "Accommodation": "The Favorite Room at The Deer House-Room 1, Cedar Rapids",
                "Event": "-",
                "Point of Interest List": [
                    " The Favorite Room at The Deer House-Room 1, stay from 09:00 to 10:00, nearest transit: 3rd Ave & 15th St, 108.77m away;"
                    " Lightworks Cafe, visit from 10:00 to 11:30, nearest trasnit: 6th St & 6th Ave, 178.56m away;" #
                    " Mount Trashmore, visit from 11:30 to 15:00, nearest transit: C St & Rapids Ave, 656.14m away;"
                    " Need Pizzeria, visit from 15:00 to 16:30, nearest transit: 3rd St & 2nd Ave, 69.92m away;"
                    " McGrath Amphitheatre, visit from 16:30 to 20:00, nearest transit: 1st St at McGrath Ampitheatre, 127.77m away;"
                    " Cheddar's Scratch Kitchen, visit from 20:00 to 22:00, nearest transit: Lindale Mall, 185.49m away;"
                    " The Favorite Room at The Deer House-Room 1, stay from 22:00 to 06:00, nearest transit: 3rd Ave & 15th St, 108.77m away."
                ]
            },
        "Day 7": {
                "Current City": "from Cedar Rapids to Atlanta", #from 3rd_dest_city to origin_city
                "Transportation": "Flight Number: F2051872, from Cedar Rapids to Atlanta, Departure Time: 06:57, Arrival Time: 09:44", # remarks:  feasible to drive 
                "Breakfast": "-",
                "Attraction": "-",
                "Lunch": "-",
                "Dinner": "-",
                "Accommodation": "The Favorite Room at The Deer House-Room 1, Cedar Rapids",
                "Event": "-",
                "Point of Interest List": [
                    " The Favorite Room at The Deer House-Room 1, stay from 06:00 to 06:30, nearest transit: 3rd Ave & 15th St, 108.77m away."
                    
                ]
        
    }

        
              

        
        # Add remaining days as needed
    }

    # Print the travel plan
    print("\nAnnotated Travel Plan:")
    for day, details in travel_plan.items():
        print(f"\n{day}:")
        for key, value in details.items():
            if isinstance(value, list):
                print(f"{key}:")
                for item in value:
                    print(f"  {item}")
            else:
                print(f"{key}: {value}")

except KeyError:
    print("Column 'reference_information' does not exist in the file.")
except IndexError:
    print(f"Row {row_number} does not exist in the file.")
except json.JSONDecodeError as e:
    print(f"JSON decoding error for row {row_number}: {e}")
# Out:
# Row 82 - Keys and Content in 'reference_information_1':
#
# Entry 1:
#   Description: Attractions in Fort Dodge
#   Content: name subcategories visit_duration address latitude longitude website
# Studio Fusion ['Shopping', 'Classes & Workshops', 'Fun & Games'] 1.5 21 S 12th St, Fort Dodge, IA 50501-4831 42.505436 -94.18243 http://Studio-fusion.com
# Blanden Art Museum ['Shopping', 'Museums'] 2.25 920 3rd Ave S, Fort Dodge, IA 50501-4723 42.50268 -94.18453 http://www.blanden.org/
# Fort Dodge Grain Silo Mural ['Sights & Landmarks'] 3.0 727 Hawkeye Ave, Fort Dodge, IA 42.51165 -94.20238
# Fort Frenzy ['Fun & Games'] 1.5 3232 1st Ave South, Fort Dodge, IA 50501-6424 42.50547 -94.15039 http://www.fortfrenzy.com/home
# Community Orchard ['Sights & Landmarks'] 3.0 2237 160th St, Fort Dodge, IA 50501-8547 42.55984 -94.19987 http://www.communityorchard.com
# ...

# %%
# Row 159 Traveler Type: Laidback Traveler; Purpose of Travel: Adventure; Spending Preference: Luxury Traveler; Location Preference: Forests/Wildlife

import pandas as pd
import json

# Load the CSV file
file_path = "final_7day_dataset.csv" #"modified_sample_54_UHRS_with_persona.csv"  # Update with the correct path if needed
df = pd.read_csv(file_path)

# Hardcoded row number (0-indexed)
row_number = 157  # Change this to the desired row number. For query in row X, make row_number = X-2

# Extract the reference_information column for the specified row
try:
    reference_data_1 = df.loc[row_number, "reference_information_1"]
    reference_data_2 = df.loc[row_number, "reference_information_2"]
    reference_data_3 = df.loc[row_number, "reference_information_3"]
    
    # Parse the JSON string into a Python object (list of dictionaries)
    parsed_data = json.loads(reference_data_1)
    parsed_data_2 = json.loads(reference_data_2)
    parsed_data_3 = json.loads(reference_data_3)
    
    # Ensure the data is a list of dictionaries
    if isinstance(parsed_data, list) and all(isinstance(d, dict) for d in parsed_data):
        print(f"Row {row_number+2} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

    if isinstance(parsed_data_2, list) and all(isinstance(d, dict) for d in parsed_data_2):
        # print(f"Row {row_number} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 9}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

    if isinstance(parsed_data_3, list) and all(isinstance(d, dict) for d in parsed_data_3):
        # print(f"Row {row_number} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data_3):
            print(f"\nEntry {idx + 15}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

except KeyError:
    print("Column 'reference_information' does not exist in the file.")
except IndexError:
    print(f"Row {row_number} does not exist in the file.")
except json.JSONDecodeError:
    print(f"Row {row_number} - 'reference_information' column is not a valid JSON string.")

import pandas as pd
import json

# Load the CSV file
file_path = "final_7day_dataset.csv"  # Update with the correct path if needed
df = pd.read_csv(file_path)

# Hardcoded row number (0-indexed)
row_number = 157  # Change this to the desired row number 79 here

# Extract the reference_information columns for the specified row
try:
    reference_data_1 = df.loc[row_number, "reference_information_1"]
    reference_data_2 = df.loc[row_number, "reference_information_2"]
    reference_data_3 = df.loc[row_number, "reference_information_3"]

    # Parse the JSON strings into Python objects (list of dictionaries)
    parsed_data = json.loads(reference_data_1)
    parsed_data_2 = json.loads(reference_data_2)
    parsed_data_3 = json.loads(reference_data_3)

    # Ensure the data is a list of dictionaries
    if isinstance(parsed_data, list) and all(isinstance(d, dict) for d in parsed_data):
        print(f"Row {row_number} - Keys and Content in 'reference_information_1':")
        for idx, dictionary in enumerate(parsed_data):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_1' is not a list of dictionaries.")

    if isinstance(parsed_data_2, list) and all(isinstance(d, dict) for d in parsed_data_2):
        print(f"\nRow {row_number} - Keys and Content in 'reference_information_2':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_2' is not a list of dictionaries.")

    if isinstance(parsed_data_3, list) and all(isinstance(d, dict) for d in parsed_data_2):
        print(f"\nRow {row_number} - Keys and Content in 'reference_information_3':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_3' is not a list of dictionaries.")    

    # Create the annotated travel plan with the adjusted format
    travel_plan = {
        "Day 1": {
            "Current City": "from Boston to Bristol",
            "Transportation": "Self-driving, Duration: 946.8766666666667 mins, Distance: 1302.7535 km, Estimated Cost: $65.14",
            "Breakfast": "Blackbird Bakery, Bristol", #skipped
            "Attraction": "Cycle the City, Bristol; Bristol Hippodrome, Bristol", # attraction in 1st destination city
            "Lunch": "Don Giovanni's Restaurant, Bristol", #lunch in 2nd destination city, mostly skipped due to travelling from dest_1 to dest_2
            "Dinner": "Cosmo Bristol, Bristol", #lunch in 2nd dest city, 
            "Accommodation": "CozyUrbanLoft, Bristol", #accomodation in 2 destination city 
            "Event": "-",
            "Point of Interest List": [
                " CozyUrbanLoft, visit from 09:00 to 10:00, nearest trasnsit: Downtown Transfer Center, 126.20m away;"
                " Blackbird Bakery, visit from 10:00 to 11:00, nearest transit: Cumberland St & Waters Alley, 84.53m away;"
                " Cycle the City, visit from 11:00 to 13:30, nearest transit: Home Depot, 6254128.85m away;"
                " Don Giovanni's Restaurant, visit from 14:00 to 16:00, nearest transit: Home Depot, 6255251.85m away;"
                " Bristol Hippodrome, visit from 16:00 to 20:00, nearest transit: Home Depot, 6254043.62m away;"
                " Cosmo Bristol, visit from 20:00 to 21:30, nearest transit: Home Depot, 6253293.00m away;"
                " CozyUrbanLoft, visit from 22:00 to 09:00, nearest trasnsit: Downtown Transfer Center, 126.20m away."
            ]
        },
        # Add remaining days as needed
        "Day 2": {
                "Current City": "Bristol", #now in 2nd_dest city
                "Transportation": "-", #no travel today 
                "Breakfast" : "Eat a Pitta, Bristol",
                "Attraction": "Wills Memorial Building And Tower Tours, Bristol; Bristol City Docks, Bristol; Bristol Museum & Art Gallery, Bristol",
                "Lunch": "Fishers Restaurant - Bristol, Bristol",
                "Dinner": "Urban Tandoor, Bristol",
                "Accommodation": "CozyUrbanLoft, Bristol",
                "Event": "-",
                "Point of Interest List": [
                    
                    " CozyUrbanLoft, visit from 09:00 to 10:00, nearest trasnsit: Downtown Transfer Center, 126.20m away;"
                    " Eat a Pitta, visit from 10:00 to 11:00, nearest transit: Home Depot, 6254489.95m away;"
                    " Wills Memorial Building And Tower Tours, visit from 11:00 to 14:00, nearest transit: Home Depot, 6253555.95m away;"
                    " Fishers Restaurant - Bristol, visit from 14:00 to 16:00, nearest transit: Home Depot, 6252544.49m away;"
                    " Bristol City Docks, visit from 16:00 to 18:00, nearest transit: Home Depot, 6253131.32m away;"
                    " Bristol Museum & Art Gallery, visit from 18:00 to 20:30, nearest transit: Home Depot, 6253515.21m away;"
                    " Urban Tandoor, visit from 20:30 to 22:00, nearest transit: Home Depot, 6254198.09m away;"
                    
                    " CozyUrbanLoft, visit from 22:00 to 09:00, nearest trasnsit: Downtown Transfer Center, 126.20m away."
                    
                ]
            },
            "Day 3": {
                "Current City": "from Bristol to Chattanooga", #travel from 1st_dest_city to 2nd_dest_city
                "Transportation": "Self-driving, Duration: 249.65166666666667 mins, Distance: 360.1764 km, Estimated Cost: $18.01", #we'll self deive from san luis obispo to san barbara 
                "Breakfast": "Cafe Bristol, Bristol", #skipped breakfast
                "Attraction": "Moon Pie General Store, Chattanooga",
                "Lunch": "-", #skipped
                "Dinner": "Firebirds Wood Fired Grill, Chattanooga",
                "Accommodation": "The Lookout Mountain, Chattanooga",
                "Event": "-",
                "Point of Interest List": [
                    " CozyUrbanLoft, visit from 09:00 to 10:00, nearest trasnsit: Downtown Transfer Center, 126.20m away;"
                    " Cafe Bristol, visit from 10:00 to 11:30, nearest transit: Home Depot, 7679840.27m away;"
                    #leaved from 3rd_dest_city
                    " The Lookout Mountain, stay from 17:00 to 17:30, nearest transit: Incline Railway TENN AVE + INCLINE, 63.48m away;"
                    " Moon Pie General Store, visit from 18:00 to 20:00, nearest transit: Broad & Jack's Alley, 46.95m away;"
                    " Firebirds Wood Fired Grill, visit from 20:30 to 22:30, nearest transit: Gunbarrel & Bus Shelter-1, 103.28m away;"
                    " The Lookout Mountain, stay from 22:30 to 09:30, nearest transit: Incline Railway TENN AVE + INCLINE, 63.48m away."
                    
                ]
            },
            "Day 4": {
                "Current City": "Chattonooga", #now explore dest_city_3
                "Transportation": "-", #no travel today 
                "Breakfast" : "Bluegrass Gril, Chattonooga",
                "Attraction": "The Lookout Mountain, Chattanooga; Chattanooga Zoo, Chattanooga; Chattanooga Ghost Tours, Chattanooga",
                "Lunch": "Zaya 1943 Korean Steakhouse, Chattanooga",
                "Dinner": "Ruth's Chris Steak House, Chattanooga",
                "Accommodation": "",
                "Event": "-",
                "Point of Interest List": [
                    " The Lookout Mountain, stay from 09:30 to 10:00, nearest transit: Incline Railway TENN AVE + INCLINE, 63.48m away;"
                    " Bluegrass Grill, visit from 10:00 to 11:00, nearest transit: MAIN + ROSSVILLE AVE, 46.22m away;"
                    " Chattanooga Zoo, visit from 11:00 to 14:00, nearest transit: Holtzclaw & 5th-1, 123.88m away;"
                    " Zaya 1943 Korean Steakhouse, visit from 14:00 to 16:00, nearest transit: MANUFACTURERS RD + CHEROKEE BLVD, 152.90m away;"
                    " Chattanooga Ghost Tours, visit from 16:00 to 19:30, nearest transit: MARKET + 5TH, 59.20m away;"
                    " Ruth's Chris Steak House, visit from 20:00 to 22:00, nearest transit: HAMILTON PLACE BLVD + BAMS, 315.44m away;"
                    " The Lookout Mountain, stay from 22:30 to 09:00, nearest transit: Incline Railway TENN AVE + INCLINE, 63.48m away."
                     
                ]
            },
            "Day 5": {
                "Current City": "from Chattanooga to Nashville", #travel 2nd_dest_city to 3rd_dest_city
                "Transportation": "Self-driving, Duration: 150.45166666666668 mins, Distance: 213.5283 km, Estimated Cost: $10.68", # remarks: not feasible to drive back from Santa Barbara to New York 
                "Breakfast": "Frothy Monkey, Chattanooga", #
                "Attraction": "The Lookout Mountain Incline Railway, Chattanooga; Grand Ole Opry, Nsshville",
                "Lunch": "-", #skipped
                "Dinner": "Luogo, Nashville",
                "Accommodation": "The Modern Johnny Nash-Walk To Broadway- HOT POOL, Nashville",
                "Event": "-",
                "Point of Interest List": [
                    " The Lookout Mountain, stay from 09:00 to 10:00, nearest transit: Incline Railway TENN AVE + INCLINE, 63.48m away;"
                    " Frothy Monkey, visit from 10:00 to 11:30, nearest transit: SHUTTLE PARK SOUTH, 58.96m away;"
                    " The Lookout Mountain Incline Railway, visit from 11:30 to 13:00, nearest transit: TENN AVE + INCLINE, 63.48m away;"
                    #leaved fro 3rd_dest_city i.e Cedar Rapids
                    " The Modern Johnny Nash-Walk To Broadway- HOT POOL, stay from 16:00 to 17:00, nearest transit: LAFAYETTE ST & EWING AVE SB, 176.49m away;"
                    " Grand Ole Opry, visit from 17:00 to 20:00, nearest transit: OPRY MILLS DR & GENERAL JACKSON'S, 377.07m away;"
                    " Luogo, visit from 20:30 to 22:00, nearest transit: 12TH AVE & LAUREL ST NB, 86.33m away"
                    " The Modern Johnny Nash-Walk To Broadway- HOT POOL, stay from 22:00 to 09:00, nearest transit: LAFAYETTE ST & EWING AVE SB, 176.49m away."

                    
                ]
            },
        "Day 6": {
                "Current City": "Nashville", #now in 2nd_dest city
                "Transportation": "-",
                "Breakfast": "1 Kitchen, Nashville", #American
                "Attraction": "Centennial Park, Nashville, RCA Studio B, Nashville; Country Music Hall of Fame and Museum, Nashville; Cooter’s Museum and Store, Nashville",
                "Lunch": "The Catbird Seat, Nashvile",
                "Dinner": "Old Hickory Steakhouse, Nashville",
                "Accommodation": "The Modern Johnny Nash-Walk To Broadway- HOT POOL, Nashville",
                "Event": "-",
                "Point of Interest List": [
                    " The Modern Johnny Nash-Walk To Broadway- HOT POOL, stay from 08:00 to 09:00, nearest transit: LAFAYETTE ST & EWING AVE SB, 176.49m away;"
                    " 1 Kitchen, visit from 09:00 to 10:00, nearest transit: 8TH AVE S & DEMONBREUN ST SB, 67.82m away;"
                    " Centennial Park, visit from 10:00 to 12:30, nearest transit: WEST END AVE & 27TH AVE S WB, 441.64m away;"
                    " RCA Studio B, visit from 12:30 to 14:00, nearest transit: BROADWAY AVE & 19TH AVE S EB, 338.29m away;"
                    " The Catbird Seat, visit from 14:00 to 15:30, nearest transit: BROADWAY AVE & 17TH AVE S EB, 189.47m away;"
                    " Country Music Hall of Fame and Museum, visit from 16:00 to 19:00, nearest transit: CONVENTION CENTER STATION OUTBOUND, 106.41m away;"
                    " Cooter’s Museum and Store Nashville, visit from 19:00 to 20:30, nearest transit: MCGAVOCK PIKE & MUSIC VALLEY DR WB, 109.02m away;"
                    " Old Hickory Steakhouse, visit from 20:30 to 22:00, nearest transit: OPRY MILLS DRIVE & WARDROBE BLDNG, 483.51m away;"
                    " The Modern Johnny Nash-Walk To Broadway- HOT POOL, stay from 22:00 to 08:00, nearest transit: LAFAYETTE ST & EWING AVE SB, 176.49m away."
                ]
            },
        "Day 7": {
                "Current City": "from Nashville to Boston", #from 3rd_dest_city to origin_city
                "Transportation": "Flight Number: F0260331, from Nashville to Boston, Departure Time: 12:21, Arrival Time: 15:36", # remarks:  feasible to drive 
                "Breakfast": "The Bluebird Cafe, Nashville",
                "Attraction": "Belmont Mansion, Nashville",
                "Lunch": "-",
                "Dinner": "-",
                "Accommodation": "The Modern Johnny Nash-Walk To Broadway- HOT POOL, Nashville",
                "Event": "-",
                "Point of Interest List": [
                    " The Modern Johnny Nash-Walk To Broadway- HOT POOL, stay from 08:00 to 09:00, nearest transit: LAFAYETTE ST & EWING AVE SB, 176.49m away;"
                    " The Bluebird Cafe, visit from 09:00 to 10:00, nearest transit: RICHARD JONES RD & HILLSBORO PIKE W, 383.04m away;"
                    " Belmont Mansion, visit from 10:00 to 12:00, nearest transit: WEDGEWOOD AVE & 16TH AVE EB, 92.02m away."
                    #leaved for Boston
                    
                ]
        
    }

        
              

        
        # Add remaining days as needed
    }

    # Print the travel plan
    print("\nAnnotated Travel Plan:")
    for day, details in travel_plan.items():
        print(f"\n{day}:")
        for key, value in details.items():
            if isinstance(value, list):
                print(f"{key}:")
                for item in value:
                    print(f"  {item}")
            else:
                print(f"{key}: {value}")

except KeyError:
    print("Column 'reference_information' does not exist in the file.")
except IndexError:
    print(f"Row {row_number} does not exist in the file.")
except json.JSONDecodeError as e:
    print(f"JSON decoding error for row {row_number}: {e}")
# Out:
# Row 159 - Keys and Content in 'reference_information':
#
# Entry 1:
#   Description: Attractions in Bristol
#   Content: name subcategories visit_duration address latitude longitude website
# Wills Memorial Building And Tower Tours ['Sights & Landmarks'] 3.0 Queens Rd, Bristol BS8 1RJ England 51.456036 -2.604578 http://www.facebook.com/willstowertours
# Bristol Museum & Art Gallery ['Shopping', 'Museums'] 2.25 Queens Road Clifton, Bristol BS8 1RL England 51.45623 -2.605093 http://www.bristolmuseums.org.uk/
# Blackbeard to Banksy the Ultimate Bristol Walking Tour ['Tours'] 3.0 College Green main entrance of the Cathedral, Bristol BS1 5TJ England 51.45186 -2.600728 http://blackbeard2banksy.com
# Escape Hunt Bristol ['Fun & Games'] 1.5 Cabot Circus, Bristol BS1 3BX England 51.458496 -2.585342 http://escapehunt.com/uk/bristol/?utm_campaign=&utm_source=TripAdvisor&utm_medium=referral&utm_content=engagement
# ...

# %%
import pandas as pd
import json

# Load the CSV file
file_path = "final_7day_dataset.csv" #"modified_sample_54_UHRS_with_persona.csv"  # Update with the correct path if needed
df = pd.read_csv(file_path)

# Hardcoded row number (0-indexed)
row_number = 157  # Change this to the desired row number. For query in row X, make row_number = X-2

# Extract the reference_information column for the specified row
try:
    reference_data_1 = df.loc[row_number, "reference_information_1"]
    reference_data_2 = df.loc[row_number, "reference_information_2"]
    reference_data_3 = df.loc[row_number, "reference_information_3"]
    
    # Parse the JSON string into a Python object (list of dictionaries)
    parsed_data = json.loads(reference_data_1)
    parsed_data_2 = json.loads(reference_data_2)
    parsed_data_3 = json.loads(reference_data_3)
    
    # Ensure the data is a list of dictionaries
    if isinstance(parsed_data, list) and all(isinstance(d, dict) for d in parsed_data):
        print(f"Row {row_number+2} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

    if isinstance(parsed_data_2, list) and all(isinstance(d, dict) for d in parsed_data_2):
        # print(f"Row {row_number} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 9}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

    if isinstance(parsed_data_3, list) and all(isinstance(d, dict) for d in parsed_data_3):
        # print(f"Row {row_number} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data_3):
            print(f"\nEntry {idx + 15}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

except KeyError:
    print("Column 'reference_information' does not exist in the file.")
except IndexError:
    print(f"Row {row_number} does not exist in the file.")
except json.JSONDecodeError:
    print(f"Row {row_number} - 'reference_information' column is not a valid JSON string.")
# Out:
# Row 159 - Keys and Content in 'reference_information':
#
# Entry 1:
#   Description: Attractions in Bristol
#   Content: name subcategories visit_duration address latitude longitude website
# Wills Memorial Building And Tower Tours ['Sights & Landmarks'] 3.0 Queens Rd, Bristol BS8 1RJ England 51.456036 -2.604578 http://www.facebook.com/willstowertours
# Bristol Museum & Art Gallery ['Shopping', 'Museums'] 2.25 Queens Road Clifton, Bristol BS8 1RL England 51.45623 -2.605093 http://www.bristolmuseums.org.uk/
# Blackbeard to Banksy the Ultimate Bristol Walking Tour ['Tours'] 3.0 College Green main entrance of the Cathedral, Bristol BS1 5TJ England 51.45186 -2.600728 http://blackbeard2banksy.com
# Escape Hunt Bristol ['Fun & Games'] 1.5 Cabot Circus, Bristol BS1 3BX England 51.458496 -2.585342 http://escapehunt.com/uk/bristol/?utm_campaign=&utm_source=TripAdvisor&utm_medium=referral&utm_content=engagement
# ...

# %% [markdown]
# # Row 160 Traveler Type: Laidback Traveler; Purpose of Travel: Adventure; Spending Preference: Economical Traveler; Location Preference: Mountains

# %%
import pandas as pd
import json

# Load the CSV file
file_path = "final_7day_dataset.csv" #"modified_sample_54_UHRS_with_persona.csv"  # Update with the correct path if needed
df = pd.read_csv(file_path)

# Hardcoded row number (0-indexed)
row_number = 158  # Change this to the desired row number. For query in row X, make row_number = X-2

# Extract the reference_information column for the specified row
try:
    reference_data_1 = df.loc[row_number, "reference_information_1"]
    reference_data_2 = df.loc[row_number, "reference_information_2"]
    reference_data_3 = df.loc[row_number, "reference_information_3"]
    
    # Parse the JSON string into a Python object (list of dictionaries)
    parsed_data = json.loads(reference_data_1)
    parsed_data_2 = json.loads(reference_data_2)
    parsed_data_3 = json.loads(reference_data_3)
    
    # Ensure the data is a list of dictionaries
    if isinstance(parsed_data, list) and all(isinstance(d, dict) for d in parsed_data):
        print(f"Row {row_number+2} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

    if isinstance(parsed_data_2, list) and all(isinstance(d, dict) for d in parsed_data_2):
        # print(f"Row {row_number} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 9}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

    if isinstance(parsed_data_3, list) and all(isinstance(d, dict) for d in parsed_data_3):
        # print(f"Row {row_number} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data_3):
            print(f"\nEntry {idx + 15}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

except KeyError:
    print("Column 'reference_information' does not exist in the file.")
except IndexError:
    print(f"Row {row_number} does not exist in the file.")
except json.JSONDecodeError:
    print(f"Row {row_number} - 'reference_information' column is not a valid JSON string.")
# Out:
# Row 160 - Keys and Content in 'reference_information':
#
# Entry 1:
#   Description: Attractions in Mason City
#   Content: name subcategories visit_duration address latitude longitude website
# Mason City Brewery ['Food & Drink'] 2.5 28 E State St, Mason City, IA 50401-3318 43.152023 -93.19985 http://www.masoncitybrewing.com/
# Stebens Theater ['Concerts & Shows'] 2.5 616 N Delaware Ave, Mason City, IA 50401-7014 43.157784 -93.19976 http://www.stebensct.com/
# Melson House ['Museums'] 3.0 56 River Heights Dr, Mason City, IA 50401-4032 43.14924 -93.19309 http://facebook.com/melsonhouseunlimited
# Rock Crest - Rock Glen Historical District ['Sights & Landmarks'] 3.0 17 S Federal Ave Off U.S. Route 18, Along Willow Creek, Mason City, IA 50401-3727 43.15118 -93.20077
# 1910 Lounge ['Nightlife', 'Sights & Landmarks'] 2.75 15 W State St, Mason City, IA 50401-3228 43.15157 -93.20167
# ...

# %%
# Row 159 Traveler Type: Laidback Traveler; Purpose of Travel: Adventure; Spending Preference: Luxury Traveler; Location Preference: Forests/Wildlife

import pandas as pd
import json

# Load the CSV file
file_path = "final_7day_dataset.csv" #"modified_sample_54_UHRS_with_persona.csv"  # Update with the correct path if needed
df = pd.read_csv(file_path)

# Hardcoded row number (0-indexed)
row_number = 158  # Change this to the desired row number. For query in row X, make row_number = X-2

# Extract the reference_information column for the specified row
try:
    reference_data_1 = df.loc[row_number, "reference_information_1"]
    reference_data_2 = df.loc[row_number, "reference_information_2"]
    reference_data_3 = df.loc[row_number, "reference_information_3"]
    
    # Parse the JSON string into a Python object (list of dictionaries)
    parsed_data = json.loads(reference_data_1)
    parsed_data_2 = json.loads(reference_data_2)
    parsed_data_3 = json.loads(reference_data_3)
    
    # Ensure the data is a list of dictionaries
    if isinstance(parsed_data, list) and all(isinstance(d, dict) for d in parsed_data):
        print(f"Row {row_number+2} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

    if isinstance(parsed_data_2, list) and all(isinstance(d, dict) for d in parsed_data_2):
        # print(f"Row {row_number} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 9}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

    if isinstance(parsed_data_3, list) and all(isinstance(d, dict) for d in parsed_data_3):
        # print(f"Row {row_number} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data_3):
            print(f"\nEntry {idx + 15}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

except KeyError:
    print("Column 'reference_information' does not exist in the file.")
except IndexError:
    print(f"Row {row_number} does not exist in the file.")
except json.JSONDecodeError:
    print(f"Row {row_number} - 'reference_information' column is not a valid JSON string.")

import pandas as pd
import json

# Load the CSV file
file_path = "final_7day_dataset.csv"  # Update with the correct path if needed
df = pd.read_csv(file_path)

# Hardcoded row number (0-indexed)
row_number = 158  # Change this to the desired row number 79 here

# Extract the reference_information columns for the specified row
try:
    reference_data_1 = df.loc[row_number, "reference_information_1"]
    reference_data_2 = df.loc[row_number, "reference_information_2"]
    reference_data_3 = df.loc[row_number, "reference_information_3"]

    # Parse the JSON strings into Python objects (list of dictionaries)
    parsed_data = json.loads(reference_data_1)
    parsed_data_2 = json.loads(reference_data_2)
    parsed_data_3 = json.loads(reference_data_3)

    # Ensure the data is a list of dictionaries
    if isinstance(parsed_data, list) and all(isinstance(d, dict) for d in parsed_data):
        print(f"Row {row_number} - Keys and Content in 'reference_information_1':")
        for idx, dictionary in enumerate(parsed_data):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_1' is not a list of dictionaries.")

    if isinstance(parsed_data_2, list) and all(isinstance(d, dict) for d in parsed_data_2):
        print(f"\nRow {row_number} - Keys and Content in 'reference_information_2':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_2' is not a list of dictionaries.")

    if isinstance(parsed_data_3, list) and all(isinstance(d, dict) for d in parsed_data_2):
        print(f"\nRow {row_number} - Keys and Content in 'reference_information_3':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_3' is not a list of dictionaries.")    

    # Create the annotated travel plan with the adjusted format
    travel_plan = {
        "Day 1": {
            "Current City": "from Detroit to Mason City",
            "Transportation": "Self-driving, Duration: 729.6166666666667 mins, Distance: 1046.8773 km, Estimated Cost: $52.34",
            "Breakfast": "-", #skipped
            "Attraction": "Lime Creek Nature Center, Mason City; Benish Studio - Art & Framing, Mason City; Fat Hill Brewing, Mason City", # attraction in 1st destination city
            "Lunch": "Mason's Famous Lobster Rolls, Mason City", #not feasible
            "Dinner": "Plaza Mexico Mason City, Mason City", #lunch in 2nd dest city, 
            "Accommodation": "Comfort on Willow, Mason City", #accomodation in 2 destination city 
            "Event": "Always Loretta Music 128 Graham Ave 2024-11-11",
            "Point of Interest List": [
                " Comfort on Willow, stay from 11:00 to 12:00, nearest transit: E State St. and 1st St. NE,121.08m away;"
                " Mason's Famous Lobster Rolls, visit from 12:00 to 14:00, nearest transit: North Iowa Area Community College, 1447620.58m away;"
                " Lime Creek Nature Center, visit from 14:00 to 15:00, nearest transit: N Pennsylvania Ave. and 17th St. NE, 1636.94m away;"
                " Benish Studio - Art & Framing, visit from 15:00 to 18:00, nearest transit: N Pennsylvania Ave. and 11th St. N, 268.06m away;"
                " Fat Hill Brewing, visit from 18:00 to 20:30, nearest transit: Central Park, 46.90m away;"
                " Plaza Mexico Mason City, visit from:20:30 to 22:30, nearest trasnit: S Pennsylvania Ave. and 19th St. SE, 187.49m away;"
                " Comfort on Willow, stay from 23:00 to 09:00, nearest transit: E State St. and 1st St. NE,121.08m away."
            ]
        },
        # Add remaining days as needed
        "Day 2": {
                "Current City": "Mason City", #now in 2nd_dest city
                "Transportation": "-", #no travel today 
                "Breakfast" : "Off the Grid: Fort Mason Center, Mason City",
                "Attraction": "Music Man Square, Mason City; T.J.Maxx, Mason City; Fat Hill Brewing; Mason City",
                "Lunch": "Two Cities Pizza Company, Mason City",
                "Dinner": "China Buffet, Mason City",
                "Accommodation": "Comfort on Willow, Mason City",
                "Event": "Blitzen Trapper Music 128 Graham Ave 2024-11-13",
                "Point of Interest List": [
                    
                    " Comfort on Willow, stay from 09:00 to 10:00, nearest transit: E State St. and 1st St. NE,121.08m away;"
                    " Off the Grid: Fort Mason Center, visit from 10:00 to 11:30, nearest transit: Best Buy, 2529214.57m away;"
                    " Music Man Square, visit from 11:30 to 13:30, nearest transit: 2nd St. SE and S Delaware Ave., 105.05m away;"
                    " Two Cities Pizza Company, visit from 13:30 to 15:00, nearest transit: North Iowa Area Community College, 850315.78m away;"
                    " T.J.Maxx, visit from 15:00 to 18:00, nearest transit: Target Super Center, 147.38m away;"
                    " Fat Hill Brewing, visit from 18:00 to 21:00, nearest transit: Central Park, 46.90m away;"
                    " China Buffet, visit from 21:00 to 22:30, nearest transit: S Taft Ave. and Frontage Rd. SW, 126.74m away;"
                    " Comfort on Willow, stay from 23:00 to 09:00, nearest transit: E State St. and 1st St. NE,121.08m away."
                    
                ]
            },
            "Day 3": {
                "Current City": "from Mason City to Cedar Rapids", #travel from 1st_dest_city to 2nd_dest_city
                "Transportation": "Self-driving, Duration: 162.18833333333333 mins, Distance: 222.99820000000003 km, Estimated Cost: $11.15", #we'll self deive from san luis obispo to san barbara 
                "Breakfast": "Masons Arms, Mason City", #skipped breakfast
                "Attraction": "Paramount theater, Cedar Rapids; ",
                "Lunch": "-", #skipped
                "Dinner": "Cobble Hill Restaurant, Cedar Rapids",
                "Accommodation": "Historic Ausadie Building Studio 2C, Cedar Rapids",
                "Event": "-",
                "Point of Interest List": [
                    " Comfort on Willow, stay from 09:00 to 10:00, nearest transit: E State St. and 1st St. NE,121.08m away;"
                    " Masons Arms, visit from 10:00 to 11:30, nearest transit: North Iowa Area Community College, 6603763.95m away;"
                    #leaved from 3rd_dest_city
                    " Historic Ausadie Building Studio 2C, stay from 16:00 to 17:00, nearest transit: 2nd Ave & 8th St, 46.43m away;"
                    " Paramount theater, visit from 17:00 to 19:00, nearest transit: GTC Bay 8, 93.12m away;"
                    " Cobble Hill Restaurant, vsiit from 20:00 to 22:00, nearest transit: 1st St & 2nd Ave (City Hall), 111.52m away;"
                    " Historic Ausadie Building Studio 2C, stay from 22:00 to 08:00, nearest transit: 2nd Ave & 8th St, 46.43m away."
                    
                ]
            },
            "Day 4": {
                "Current City": "Cedar Rapids", #now explore dest_city_3
                "Transportation": "-", #no travel today 
                "Breakfast" : "Cobble Hill Restaurant, Cedar Rapids",
                "Attraction": "Ushers Ferry Historic Village, Cedar Rapids; Mount Trashmore, Cedar Rapids",
                "Lunch": "The Blind Pig, Cedar Rapids",
                "Dinner": "Vino's Italian Ristorante, Cedar Rapids",
                "Accommodation": "Historic Ausadie Building Studio 2C, Cedar Rapids",
                "Event": "Wooli Presents: The Mind Warp Tour Music 25 S. Livingston Street 2024-11-14",
                "Point of Interest List": [
                    " Historic Ausadie Building Studio 2C, stay from 16:00 to 17:00, nearest transit: 2nd Ave & 8th St, 46.43m away;"
                    " Cobble Hill Restaurant, visit from 10:00 to 11:30, nearest transit: 1st St & 2nd Ave (City Hall), 111.52m away;"
                    " Ushers Ferry Historic Village, visit from 11:30 to 14:00, nearest transit: Edgewood Rd & O Ave, 2020.86m away;"
                    " The Blind Pig, visit from 14:00 to 15:30, nearest transit: 3335 Center Point Rd (Papa Murph), 140.18m away;"
                    " Mount Trashmore, visit from 16:00 to 20:00, nearest transit: C St & Rapids Ave, 656.14m away;"
                    " Vino's Italian Ristorante, visit from 20:00 to 22:00, nearest transit: 1st Ave & 38th St Dr, 181.60m away;"
                    " Historic Ausadie Building Studio 2C, stay from 22:00 to 09:00, nearest transit: 2nd Ave & 8th St, 46.43m away."
                     
                ]
            },
            "Day 5": {
                "Current City": "from Cedar Rapids to Fort Dodge", #travel 2nd_dest_city to 3rd_dest_city
                "Transportation": "Self-driving, Duration: 180.19166666666666 mins, Distance: 248.7788 km, Estimated Cost: $12.44", # remarks: not feasible to drive back from Santa Barbara to New York 
                "Breakfast": "Lightworks Cafe, Cedar Rapids", #
                "Attraction": "Fort Dodge Grain Silo Mural, Fort Dodge; Fort Frenzy, Fort Dodge",
                "Lunch": "-", #skipped
                "Dinner": "Applebee's, Fort Dodge",
                "Accommodation": "#18 One bedroom Apt, Fort Dodge",
                "Event": "-",
                "Point of Interest List": [
                    " Historic Ausadie Building Studio 2C, stay from 16:00 to 17:00, nearest transit: 2nd Ave & 8th St, 46.43m away;"
                    " Lightworks Cafe, visit from 09:00 to 10:30, nearest transit: 6th St & 6th Ave, 178.56m away;"
                    #leaved fro 3rd_dest_city i.e Cedar Rapids
                    " #18 One bedroom Apt, stay from 14:00 to 15:00, nearest transit: S 7th St and 2nd Ave S,  102.01m away;"
                    " Fort Dodge Grain Silo Mural, visit from 15:00 to 17:00, nearest trasnit: 7th Ave N and Hawkeye Ave, 133.89m away;"
                    " Fort Frenzy, visit from 17:30 to 20:00, nearest transit: 1st Ave S and S 31st St, 108.41m away;"
                    " Applebee's, visit from 20:30 to 22:00, nearest transit: Crossroads Mall Entrance/Younkers, 209.17m away;"
                    " #18 One bedroom Apt, stay from 22:00 to 08:00, nearest transit: S 7th St and 2nd Ave S,  102.01m away."

                    
                ]
            },
        "Day 6": {
                "Current City": "Fort Dodge", #now in 2nd_dest city
                "Transportation": "-",
                "Breakfast": "Central Perk and Dessert, Fort Dodge", #American
                "Attraction": "Studio Fusion, Fort Dodge; Community Orchard, Fort Dodge",
                "Lunch": "Tom Thumb Drive Inn, Fort Dodge",
                "Dinner": "Gaga & Hoo, Fort Dodge",
                "Accommodation": "#18 One bedroom Apt, Fort Dodge",
                "Event": "Drake Bulldogs Mens Basketball vs. Florida Gulf Coast Eagles Mens Basketball Sports 2507 University Ave 2024-11-16",
                "Point of Interest List": [
                    " #18 One bedroom Apt, stay from 08:00 to 09:00, nearest transit: S 7th St and 2nd Ave S,  102.01m away;"
                    " Central Perk and Dessert, visit from 09:00 to 10:30, nearest transit: Central Ave and S 13th St, 105.71m away;"
                    " Studio Fusion, visit from 10:30 to 12:00, nearest transit: N 11th St and Central Ave, 71.87m away;"
                    " Tom Thumb Drive Inn, visit from 13:00 to 15:00, nearest transit: A St and Ave O W, 90.84m away;"
                    " Community Orchard, visit from 15:00 to 19:00, nearest transit: Village Green, 3093.21m away;"
                    " Gaga & Hoo, visit from 19:30 to 21:00,  nearest transit: Ave C and C St, 657.59m away;"
                    " #18 One bedroom Apt, stay from 22:00 to 08:00, nearest transit: S 7th St and 2nd Ave S,  102.01m away."
                    
                ]
            },
        "Day 7": {
                "Current City": "from Fort Dodge to Detroit", #from 3rd_dest_city to origin_city
                "Transportation": "Self-driving, Duration: 748.2833333333333 mins, Distance: 1072.9909 km, Estimated Cost: $53.65", # remarks:  feasible to drive 
                "Breakfast": "A Pinch Of Love Cafe, Fort Dodge",
                "Attraction": "",
                "Lunch": "-",
                "Dinner": "-",
                "Accommodation": "#18 One bedroom Apt, Fort Dodge",
                "Event": "John Deere Quad Cities Showdown Sports 1201 River Dr 2024-11-15",
                "Point of Interest List": [
                    " #18 One bedroom Apt, stay from 08:00 to 09:00, nearest transit: S 7th St and 2nd Ave S,  102.01m away;"
                    " A Pinch Of Love Cafe, visit from 09:00 to 11:00, nearest transit: Fort Dodge Housing Authority, 212.51m away;" 
                    " Soldier Creek Winery, visit from 11:00 to 13:00, nearest transit: Village Green, 3639.86m away."
                    #leaved for Detroit
                    
                ]
        
    }

        
              

        
        # Add remaining days as needed
    }

    # Print the travel plan
    print("\nAnnotated Travel Plan:")
    for day, details in travel_plan.items():
        print(f"\n{day}:")
        for key, value in details.items():
            if isinstance(value, list):
                print(f"{key}:")
                for item in value:
                    print(f"  {item}")
            else:
                print(f"{key}: {value}")

except KeyError:
    print("Column 'reference_information' does not exist in the file.")
except IndexError:
    print(f"Row {row_number} does not exist in the file.")
except json.JSONDecodeError as e:
    print(f"JSON decoding error for row {row_number}: {e}")
# Out:
# Row 160 - Keys and Content in 'reference_information':
#
# Entry 1:
#   Description: Attractions in Mason City
#   Content: name subcategories visit_duration address latitude longitude website
# Mason City Brewery ['Food & Drink'] 2.5 28 E State St, Mason City, IA 50401-3318 43.152023 -93.19985 http://www.masoncitybrewing.com/
# Stebens Theater ['Concerts & Shows'] 2.5 616 N Delaware Ave, Mason City, IA 50401-7014 43.157784 -93.19976 http://www.stebensct.com/
# Melson House ['Museums'] 3.0 56 River Heights Dr, Mason City, IA 50401-4032 43.14924 -93.19309 http://facebook.com/melsonhouseunlimited
# Rock Crest - Rock Glen Historical District ['Sights & Landmarks'] 3.0 17 S Federal Ave Off U.S. Route 18, Along Willow Creek, Mason City, IA 50401-3727 43.15118 -93.20077
# 1910 Lounge ['Nightlife', 'Sights & Landmarks'] 2.75 15 W State St, Mason City, IA 50401-3228 43.15157 -93.20167
# ...

# %% [markdown]
# # Tweaked Row 160

# %%
import pandas as pd
import json

# Load the CSV file
file_path = "final_7day_dataset.csv" #"modified_sample_54_UHRS_with_persona.csv"  # Update with the correct path if needed
df = pd.read_csv(file_path)

# Hardcoded row number (0-indexed)
row_number = 158  # Change this to the desired row number. For query in row X, make row_number = X-2

# Extract the reference_information column for the specified row
try:
    reference_data_1 = df.loc[row_number, "reference_information_1"]
    reference_data_2 = df.loc[row_number, "reference_information_2"]
    reference_data_3 = df.loc[row_number, "reference_information_3"]
    
    # Parse the JSON string into a Python object (list of dictionaries)
    parsed_data = json.loads(reference_data_1)
    parsed_data_2 = json.loads(reference_data_2)
    parsed_data_3 = json.loads(reference_data_3)
    
    # Ensure the data is a list of dictionaries
    if isinstance(parsed_data, list) and all(isinstance(d, dict) for d in parsed_data):
        print(f"Row {row_number+2} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

    if isinstance(parsed_data_2, list) and all(isinstance(d, dict) for d in parsed_data_2):
        # print(f"Row {row_number} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 9}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

    if isinstance(parsed_data_3, list) and all(isinstance(d, dict) for d in parsed_data_3):
        # print(f"Row {row_number} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data_3):
            print(f"\nEntry {idx + 15}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

except KeyError:
    print("Column 'reference_information' does not exist in the file.")
except IndexError:
    print(f"Row {row_number} does not exist in the file.")
except json.JSONDecodeError:
    print(f"Row {row_number} - 'reference_information' column is not a valid JSON string.")
# Out:
# Row 160 - Keys and Content in 'reference_information':
#
# Entry 1:
#   Description: Attractions in Mason City
#   Content: name subcategories visit_duration address latitude longitude website
# Mason City Brewery ['Food & Drink'] 2.5 28 E State St, Mason City, IA 50401-3318 43.152023 -93.19985 http://www.masoncitybrewing.com/
# Stebens Theater ['Concerts & Shows'] 2.5 616 N Delaware Ave, Mason City, IA 50401-7014 43.157784 -93.19976 http://www.stebensct.com/
# Melson House ['Museums'] 3.0 56 River Heights Dr, Mason City, IA 50401-4032 43.14924 -93.19309 http://facebook.com/melsonhouseunlimited
# Rock Crest - Rock Glen Historical District ['Sights & Landmarks'] 3.0 17 S Federal Ave Off U.S. Route 18, Along Willow Creek, Mason City, IA 50401-3727 43.15118 -93.20077
# 1910 Lounge ['Nightlife', 'Sights & Landmarks'] 2.75 15 W State St, Mason City, IA 50401-3228 43.15157 -93.20167
# ...

# %%
# Row 159 Traveler Type: Laidback Traveler; Purpose of Travel: Adventure; Spending Preference: Luxury Traveler; Location Preference: Forests/Wildlife

import pandas as pd
import json

# Load the CSV file
file_path = "final_7day_dataset.csv" #"modified_sample_54_UHRS_with_persona.csv"  # Update with the correct path if needed
df = pd.read_csv(file_path)

# Hardcoded row number (0-indexed)
row_number = 158  # Change this to the desired row number. For query in row X, make row_number = X-2

# Extract the reference_information column for the specified row
try:
    reference_data_1 = df.loc[row_number, "reference_information_1"]
    reference_data_2 = df.loc[row_number, "reference_information_2"]
    reference_data_3 = df.loc[row_number, "reference_information_3"]
    
    # Parse the JSON string into a Python object (list of dictionaries)
    parsed_data = json.loads(reference_data_1)
    parsed_data_2 = json.loads(reference_data_2)
    parsed_data_3 = json.loads(reference_data_3)
    
    # Ensure the data is a list of dictionaries
    if isinstance(parsed_data, list) and all(isinstance(d, dict) for d in parsed_data):
        print(f"Row {row_number+2} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

    if isinstance(parsed_data_2, list) and all(isinstance(d, dict) for d in parsed_data_2):
        # print(f"Row {row_number} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 9}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

    if isinstance(parsed_data_3, list) and all(isinstance(d, dict) for d in parsed_data_3):
        # print(f"Row {row_number} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data_3):
            print(f"\nEntry {idx + 15}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

except KeyError:
    print("Column 'reference_information' does not exist in the file.")
except IndexError:
    print(f"Row {row_number} does not exist in the file.")
except json.JSONDecodeError:
    print(f"Row {row_number} - 'reference_information' column is not a valid JSON string.")

import pandas as pd
import json

# Load the CSV file
file_path = "final_7day_dataset.csv"  # Update with the correct path if needed
df = pd.read_csv(file_path)

# Hardcoded row number (0-indexed)
row_number = 158  # Change this to the desired row number 79 here

# Extract the reference_information columns for the specified row
try:
    reference_data_1 = df.loc[row_number, "reference_information_1"]
    reference_data_2 = df.loc[row_number, "reference_information_2"]
    reference_data_3 = df.loc[row_number, "reference_information_3"]

    # Parse the JSON strings into Python objects (list of dictionaries)
    parsed_data = json.loads(reference_data_1)
    parsed_data_2 = json.loads(reference_data_2)
    parsed_data_3 = json.loads(reference_data_3)

    # Ensure the data is a list of dictionaries
    if isinstance(parsed_data, list) and all(isinstance(d, dict) for d in parsed_data):
        print(f"Row {row_number} - Keys and Content in 'reference_information_1':")
        for idx, dictionary in enumerate(parsed_data):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_1' is not a list of dictionaries.")

    if isinstance(parsed_data_2, list) and all(isinstance(d, dict) for d in parsed_data_2):
        print(f"\nRow {row_number} - Keys and Content in 'reference_information_2':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_2' is not a list of dictionaries.")

    if isinstance(parsed_data_3, list) and all(isinstance(d, dict) for d in parsed_data_2):
        print(f"\nRow {row_number} - Keys and Content in 'reference_information_3':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_3' is not a list of dictionaries.")    

    # Create the annotated travel plan with the adjusted format
    travel_plan = {
        "Day 1": {
            "Current City": "from Detroit to Mason City",
            "Transportation": "Self-driving, Duration: 729.6166666666667 mins, Distance: 1046.8773 km, Estimated Cost: $52.34",
            "Breakfast": "-", #skipped
            "Attraction": "Lime Creek Nature Center, Mason City; Benish Studio - Art & Framing, Mason City; Fat Hill Brewing, Mason City", # attraction in 1st destination city
            "Lunch": "Taco Tico, Mason City", #not feasible
            "Dinner": "Plaza Mexico Mason City, Mason City", #lunch in 2nd dest city, 
            "Accommodation": "Comfort on Willow, Mason City", #accomodation in 2 destination city 
            "Event": "Always Loretta Music 128 Graham Ave 2024-11-11",
            "Point of Interest List": [
                " Comfort on Willow, stay from 11:00 to 12:00, nearest transit: E State St. and 1st St. NE,121.08m away;"
                " Taco Tico, visit from 12:00 to 13:00, nearest transit: Frontage Rd. SW and Briarstone Dr. (Perkins) 161.65m away;" #tweaked breakfast
                " Lime Creek Nature Center, visit from 14:00 to 15:00, nearest transit: N Pennsylvania Ave. and 17th St. NE, 1636.94m away;"
                " Benish Studio - Art & Framing, visit from 15:00 to 18:00, nearest transit: N Pennsylvania Ave. and 11th St. N, 268.06m away;"
                " Fat Hill Brewing, visit from 18:00 to 20:30, nearest transit: Central Park, 46.90m away;"
                " Plaza Mexico Mason City, visit from:20:30 to 22:30, nearest trasnit: S Pennsylvania Ave. and 19th St. SE, 187.49m away;"
                " Comfort on Willow, stay from 23:00 to 09:00, nearest transit: E State St. and 1st St. NE,121.08m away."
            ]
        },
        # Add remaining days as needed
        "Day 2": {
                "Current City": "Mason City", #now in 2nd_dest city
                "Transportation": "-", #no travel today 
                "Breakfast" : "Birdsall's, Mason City",
                "Attraction": "Music Man Square, Mason City; T.J.Maxx, Mason City; Fat Hill Brewing; Mason City",
                "Lunch": "Wok and Roll, Mason City",
                "Dinner": "China Buffet, Mason City",
                "Accommodation": "Comfort on Willow, Mason City",
                "Event": "Blitzen Trapper Music 128 Graham Ave 2024-11-13",
                "Point of Interest List": [
                    
                    " Comfort on Willow, stay from 09:00 to 10:00, nearest transit: E State St. and 1st St. NE,121.08m away;"
                    " Birdsall's, visit from 10:00 to 11:30, nearest transit: Fareway, 155.13m away;" #tweaked
                    " Music Man Square, visit from 11:30 to 13:30, nearest transit: 2nd St. SE and S Delaware Ave., 105.05m away;"
                    " Wok and Roll, visit from 13:30 to 15:00, nearest transit: S Delaware Ave. and 2nd St. SW, 132.04m away;" #tweaked
                    " T.J.Maxx, visit from 15:00 to 18:00, nearest transit: Target Super Center, 147.38m away;"
                    " Fat Hill Brewing, visit from 18:00 to 21:00, nearest transit: Central Park, 46.90m away;"
                    " China Buffet, visit from 21:00 to 22:30, nearest transit: S Taft Ave. and Frontage Rd. SW, 126.74m away;"
                    " Comfort on Willow, stay from 23:00 to 09:00, nearest transit: E State St. and 1st St. NE,121.08m away."
                    
                ]
            },
            "Day 3": {
                "Current City": "from Mason City to Cedar Rapids", #travel from 1st_dest_city to 2nd_dest_city
                "Transportation": "Self-driving, Duration: 162.18833333333333 mins, Distance: 222.99820000000003 km, Estimated Cost: $11.15", #we'll self deive from san luis obispo to san barbara 
                "Breakfast": "RibCrib BBQ, Mason City", #skipped breakfast
                "Attraction": "Paramount theater, Cedar Rapids; ",
                "Lunch": "-", #skipped
                "Dinner": "Cobble Hill Restaurant, Cedar Rapids",
                "Accommodation": "Historic Ausadie Building Studio 2C, Cedar Rapids",
                "Event": "-",
                "Point of Interest List": [
                    " Comfort on Willow, stay from 09:00 to 10:00, nearest transit: E State St. and 1st St. NE,121.08m away;"
                    " RibCrib BBQ, visit from 10:00 to 11:30, nearest transit: Frontage Rd. NW (McGregor Furniture), 106.13m away;" #tweaked
                    #leaved from 3rd_dest_city
                    " Historic Ausadie Building Studio 2C, stay from 16:00 to 17:00, nearest transit: 2nd Ave & 8th St, 46.43m away;"
                    " Paramount theater, visit from 17:00 to 19:00, nearest transit: GTC Bay 8, 93.12m away;" #concerts and shows
                    " Cobble Hill Restaurant, vsiit from 20:00 to 22:00, nearest transit: 1st St & 2nd Ave (City Hall), 111.52m away;"
                    " Historic Ausadie Building Studio 2C, stay from 22:00 to 08:00, nearest transit: 2nd Ave & 8th St, 46.43m away."
                    
                ]
            },
            "Day 4": {
                "Current City": "Cedar Rapids", #now explore dest_city_3
                "Transportation": "-", #no travel today 
                "Breakfast" : "Cobble Hill Restaurant, Cedar Rapids",
                "Attraction": "Ushers Ferry Historic Village, Cedar Rapids; Mount Trashmore, Cedar Rapids",
                "Lunch": "The Blind Pig, Cedar Rapids",
                "Dinner": "Vino's Italian Ristorante, Cedar Rapids",
                "Accommodation": "Historic Ausadie Building Studio 2C, Cedar Rapids",
                "Event": "Wooli Presents: The Mind Warp Tour Music 25 S. Livingston Street 2024-11-14",
                "Point of Interest List": [
                    " Historic Ausadie Building Studio 2C, stay from 16:00 to 17:00, nearest transit: 2nd Ave & 8th St, 46.43m away;"
                    " Cobble Hill Restaurant, visit from 10:00 to 11:30, nearest transit: 1st St & 2nd Ave (City Hall), 111.52m away;"
                    " Ushers Ferry Historic Village, visit from 11:30 to 14:00, nearest transit: Edgewood Rd & O Ave, 2020.86m away;"
                    " The Blind Pig, visit from 14:00 to 15:30, nearest transit: 3335 Center Point Rd (Papa Murph), 140.18m away;"
                    " Mount Trashmore, visit from 16:00 to 20:00, nearest transit: C St & Rapids Ave, 656.14m away;"
                    " Vino's Italian Ristorante, visit from 20:00 to 22:00, nearest transit: 1st Ave & 38th St Dr, 181.60m away;"
                    " Historic Ausadie Building Studio 2C, stay from 22:00 to 09:00, nearest transit: 2nd Ave & 8th St, 46.43m away."
                     
                ]
            },
            "Day 5": {
                "Current City": "from Cedar Rapids to Fort Dodge", #travel 2nd_dest_city to 3rd_dest_city
                "Transportation": "Self-driving, Duration: 180.19166666666666 mins, Distance: 248.7788 km, Estimated Cost: $12.44", # remarks: not feasible to drive back from Santa Barbara to New York 
                "Breakfast": "Lightworks Cafe, Cedar Rapids", #
                "Attraction": "Fort Dodge Grain Silo Mural, Fort Dodge; Fort Frenzy, Fort Dodge",
                "Lunch": "-", #skipped
                "Dinner": "Applebee's, Fort Dodge",
                "Accommodation": "#18 One bedroom Apt, Fort Dodge",
                "Event": "-",
                "Point of Interest List": [
                    " Historic Ausadie Building Studio 2C, stay from 16:00 to 17:00, nearest transit: 2nd Ave & 8th St, 46.43m away;"
                    " Lightworks Cafe, visit from 09:00 to 10:30, nearest transit: 6th St & 6th Ave, 178.56m away;"
                    #leaved fro 3rd_dest_city i.e Cedar Rapids
                    " #18 One bedroom Apt, stay from 14:00 to 15:00, nearest transit: S 7th St and 2nd Ave S,  102.01m away;"
                    " Fort Dodge Grain Silo Mural, visit from 15:00 to 17:00, nearest trasnit: 7th Ave N and Hawkeye Ave, 133.89m away;"
                    " Fort Frenzy, visit from 17:30 to 20:00, nearest transit: 1st Ave S and S 31st St, 108.41m away;"
                    " Applebee's, visit from 20:30 to 22:00, nearest transit: Crossroads Mall Entrance/Younkers, 209.17m away;"
                    " #18 One bedroom Apt, stay from 22:00 to 08:00, nearest transit: S 7th St and 2nd Ave S,  102.01m away."

                    
                ]
            },
        "Day 6": {
                "Current City": "Fort Dodge", #now in 2nd_dest city
                "Transportation": "-",
                "Breakfast": "Central Perk and Dessert, Fort Dodge", #American
                "Attraction": "Studio Fusion, Fort Dodge; Community Orchard, Fort Dodge",
                "Lunch": "Tom Thumb Drive Inn, Fort Dodge",
                "Dinner": "Gaga & Hoo, Fort Dodge",
                "Accommodation": "#18 One bedroom Apt, Fort Dodge",
                "Event": "Drake Bulldogs Mens Basketball vs. Florida Gulf Coast Eagles Mens Basketball Sports 2507 University Ave 2024-11-16",
                "Point of Interest List": [
                    " #18 One bedroom Apt, stay from 08:00 to 09:00, nearest transit: S 7th St and 2nd Ave S,  102.01m away;"
                    " Central Perk and Dessert, visit from 09:00 to 10:30, nearest transit: Central Ave and S 13th St, 105.71m away;"
                    " Studio Fusion, visit from 10:30 to 12:00, nearest transit: N 11th St and Central Ave, 71.87m away;"
                    " Tom Thumb Drive Inn, visit from 13:00 to 15:00, nearest transit: A St and Ave O W, 90.84m away;"
                    " Community Orchard, visit from 15:00 to 19:00, nearest transit: Village Green, 3093.21m away;"
                    " Gaga & Hoo, visit from 19:30 to 21:00,  nearest transit: Ave C and C St, 657.59m away;"
                    " #18 One bedroom Apt, stay from 22:00 to 08:00, nearest transit: S 7th St and 2nd Ave S,  102.01m away."
                    
                ]
            },
        "Day 7": {
                "Current City": "from Fort Dodge to Detroit", #from 3rd_dest_city to origin_city
                "Transportation": "Self-driving, Duration: 748.2833333333333 mins, Distance: 1072.9909 km, Estimated Cost: $53.65", # remarks:  feasible to drive 
                "Breakfast": "A Pinch Of Love Cafe, Fort Dodge",
                "Attraction": "",
                "Lunch": "-",
                "Dinner": "-",
                "Accommodation": "#18 One bedroom Apt, Fort Dodge",
                "Event": "John Deere Quad Cities Showdown Sports 1201 River Dr 2024-11-15",
                "Point of Interest List": [
                    " #18 One bedroom Apt, stay from 08:00 to 09:00, nearest transit: S 7th St and 2nd Ave S,  102.01m away;"
                    " A Pinch Of Love Cafe, visit from 09:00 to 11:00, nearest transit: Fort Dodge Housing Authority, 212.51m away;" 
                    " Soldier Creek Winery, visit from 11:00 to 13:00, nearest transit: Village Green, 3639.86m away."
                    #leaved for Detroit
                    
                ]
        
    }

        
              

        
        # Add remaining days as needed
    }

    # Print the travel plan
    print("\nAnnotated Travel Plan:")
    for day, details in travel_plan.items():
        print(f"\n{day}:")
        for key, value in details.items():
            if isinstance(value, list):
                print(f"{key}:")
                for item in value:
                    print(f"  {item}")
            else:
                print(f"{key}: {value}")

except KeyError:
    print("Column 'reference_information' does not exist in the file.")
except IndexError:
    print(f"Row {row_number} does not exist in the file.")
except json.JSONDecodeError as e:
    print(f"JSON decoding error for row {row_number}: {e}")
# Out:
# Row 160 - Keys and Content in 'reference_information':
#
# Entry 1:
#   Description: Attractions in Mason City
#   Content: name subcategories visit_duration address latitude longitude website
# Mason City Brewery ['Food & Drink'] 2.5 28 E State St, Mason City, IA 50401-3318 43.152023 -93.19985 http://www.masoncitybrewing.com/
# Stebens Theater ['Concerts & Shows'] 2.5 616 N Delaware Ave, Mason City, IA 50401-7014 43.157784 -93.19976 http://www.stebensct.com/
# Melson House ['Museums'] 3.0 56 River Heights Dr, Mason City, IA 50401-4032 43.14924 -93.19309 http://facebook.com/melsonhouseunlimited
# Rock Crest - Rock Glen Historical District ['Sights & Landmarks'] 3.0 17 S Federal Ave Off U.S. Route 18, Along Willow Creek, Mason City, IA 50401-3727 43.15118 -93.20077
# 1910 Lounge ['Nightlife', 'Sights & Landmarks'] 2.75 15 W State St, Mason City, IA 50401-3228 43.15157 -93.20167
# ...

# %% [markdown]
# # Tweaked Row 159 Medium to Hard

# %%
import pandas as pd
import json

# Load the CSV file
file_path = "final_7day_dataset.csv" #"modified_sample_54_UHRS_with_persona.csv"  # Update with the correct path if needed
df = pd.read_csv(file_path)

# Hardcoded row number (0-indexed)
row_number = 157  # Change this to the desired row number. For query in row X, make row_number = X-2

# Extract the reference_information column for the specified row
try:
    reference_data_1 = df.loc[row_number, "reference_information_1"]
    reference_data_2 = df.loc[row_number, "reference_information_2"]
    reference_data_3 = df.loc[row_number, "reference_information_3"]
    
    # Parse the JSON string into a Python object (list of dictionaries)
    parsed_data = json.loads(reference_data_1)
    parsed_data_2 = json.loads(reference_data_2)
    parsed_data_3 = json.loads(reference_data_3)
    
    # Ensure the data is a list of dictionaries
    if isinstance(parsed_data, list) and all(isinstance(d, dict) for d in parsed_data):
        print(f"Row {row_number+2} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

    if isinstance(parsed_data_2, list) and all(isinstance(d, dict) for d in parsed_data_2):
        # print(f"Row {row_number} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 9}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

    if isinstance(parsed_data_3, list) and all(isinstance(d, dict) for d in parsed_data_3):
        # print(f"Row {row_number} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data_3):
            print(f"\nEntry {idx + 15}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

except KeyError:
    print("Column 'reference_information' does not exist in the file.")
except IndexError:
    print(f"Row {row_number} does not exist in the file.")
except json.JSONDecodeError:
    print(f"Row {row_number} - 'reference_information' column is not a valid JSON string.")
# Out:
# Row 159 - Keys and Content in 'reference_information':
#
# Entry 1:
#   Description: Attractions in Bristol
#   Content: name subcategories visit_duration address latitude longitude website
# Wills Memorial Building And Tower Tours ['Sights & Landmarks'] 3.0 Queens Rd, Bristol BS8 1RJ England 51.456036 -2.604578 http://www.facebook.com/willstowertours
# Bristol Museum & Art Gallery ['Shopping', 'Museums'] 2.25 Queens Road Clifton, Bristol BS8 1RL England 51.45623 -2.605093 http://www.bristolmuseums.org.uk/
# Blackbeard to Banksy the Ultimate Bristol Walking Tour ['Tours'] 3.0 College Green main entrance of the Cathedral, Bristol BS1 5TJ England 51.45186 -2.600728 http://blackbeard2banksy.com
# Escape Hunt Bristol ['Fun & Games'] 1.5 Cabot Circus, Bristol BS1 3BX England 51.458496 -2.585342 http://escapehunt.com/uk/bristol/?utm_campaign=&utm_source=TripAdvisor&utm_medium=referral&utm_content=engagement
# ...

# %%
# Row 159 Traveler Type: Laidback Traveler; Purpose of Travel: Adventure; Spending Preference: Luxury Traveler; Location Preference: Forests/Wildlife

import pandas as pd
import json

# Load the CSV file
file_path = "final_7day_dataset.csv" #"modified_sample_54_UHRS_with_persona.csv"  # Update with the correct path if needed
df = pd.read_csv(file_path)

# Hardcoded row number (0-indexed)
row_number = 157  # Change this to the desired row number. For query in row X, make row_number = X-2

# Extract the reference_information column for the specified row
try:
    reference_data_1 = df.loc[row_number, "reference_information_1"]
    reference_data_2 = df.loc[row_number, "reference_information_2"]
    reference_data_3 = df.loc[row_number, "reference_information_3"]
    
    # Parse the JSON string into a Python object (list of dictionaries)
    parsed_data = json.loads(reference_data_1)
    parsed_data_2 = json.loads(reference_data_2)
    parsed_data_3 = json.loads(reference_data_3)
    
    # Ensure the data is a list of dictionaries
    if isinstance(parsed_data, list) and all(isinstance(d, dict) for d in parsed_data):
        print(f"Row {row_number+2} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

    if isinstance(parsed_data_2, list) and all(isinstance(d, dict) for d in parsed_data_2):
        # print(f"Row {row_number} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 9}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

    if isinstance(parsed_data_3, list) and all(isinstance(d, dict) for d in parsed_data_3):
        # print(f"Row {row_number} - Keys and Content in 'reference_information':")
        for idx, dictionary in enumerate(parsed_data_3):
            print(f"\nEntry {idx + 15}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information' is not a list of dictionaries.")

except KeyError:
    print("Column 'reference_information' does not exist in the file.")
except IndexError:
    print(f"Row {row_number} does not exist in the file.")
except json.JSONDecodeError:
    print(f"Row {row_number} - 'reference_information' column is not a valid JSON string.")

import pandas as pd
import json

# Load the CSV file
file_path = "final_7day_dataset.csv"  # Update with the correct path if needed
df = pd.read_csv(file_path)

# Hardcoded row number (0-indexed)
row_number = 157  # Change this to the desired row number 79 here

# Extract the reference_information columns for the specified row
try:
    reference_data_1 = df.loc[row_number, "reference_information_1"]
    reference_data_2 = df.loc[row_number, "reference_information_2"]
    reference_data_3 = df.loc[row_number, "reference_information_3"]

    # Parse the JSON strings into Python objects (list of dictionaries)
    parsed_data = json.loads(reference_data_1)
    parsed_data_2 = json.loads(reference_data_2)
    parsed_data_3 = json.loads(reference_data_3)

    # Ensure the data is a list of dictionaries
    if isinstance(parsed_data, list) and all(isinstance(d, dict) for d in parsed_data):
        print(f"Row {row_number} - Keys and Content in 'reference_information_1':")
        for idx, dictionary in enumerate(parsed_data):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_1' is not a list of dictionaries.")

    if isinstance(parsed_data_2, list) and all(isinstance(d, dict) for d in parsed_data_2):
        print(f"\nRow {row_number} - Keys and Content in 'reference_information_2':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_2' is not a list of dictionaries.")

    if isinstance(parsed_data_3, list) and all(isinstance(d, dict) for d in parsed_data_2):
        print(f"\nRow {row_number} - Keys and Content in 'reference_information_3':")
        for idx, dictionary in enumerate(parsed_data_2):
            print(f"\nEntry {idx + 1}:")
            for key, value in dictionary.items():
                print(f"  {key}: {value}")
    else:
        print(f"Row {row_number} - Data in 'reference_information_3' is not a list of dictionaries.")    

    # Create the annotated travel plan with the adjusted format
    travel_plan = {
        "Day 1": {
            "Current City": "from Boston to Bristol",
            "Transportation": "Self-driving, Duration: 946.8766666666667 mins, Distance: 1302.7535 km, Estimated Cost: $65.14",
            "Breakfast": "Blackbird Bakery, Bristol", #skipped
            "Attraction": "Cycle the City, Bristol; Bristol Hippodrome, Bristol", # attraction in 1st destination city
            "Lunch": "Don Giovanni's Restaurant, Bristol", #lunch in 2nd destination city, mostly skipped due to travelling from dest_1 to dest_2
            "Dinner": "Cosmo Bristol, Bristol", #lunch in 2nd dest city, 
            "Accommodation": "CozyUrbanLoft, Bristol", #accomodation in 2 destination city 
            "Event": "-",
            "Point of Interest List": [
                " CozyUrbanLoft, visit from 09:00 to 10:00, nearest trasnsit: Downtown Transfer Center, 126.20m away;"
                " Blackbird Bakery, visit from 10:00 to 11:00, nearest transit: Cumberland St & Waters Alley, 84.53m away;"
                " Cycle the City, visit from 11:00 to 13:30, nearest transit: Home Depot, 6254128.85m away;"
                " Don Giovanni's Restaurant, visit from 14:00 to 16:00, nearest transit: Home Depot, 6255251.85m away;"
                " Bristol Hippodrome, visit from 16:00 to 20:00, nearest transit: Home Depot, 6254043.62m away;"
                " Cosmo Bristol, visit from 20:00 to 21:30, nearest transit: Home Depot, 6253293.00m away;"
                " CozyUrbanLoft, visit from 22:00 to 09:00, nearest trasnsit: Downtown Transfer Center, 126.20m away."
            ]
        },
        # Add remaining days as needed
        "Day 2": {
                "Current City": "Bristol", #now in 2nd_dest city
                "Transportation": "-", #no travel today 
                "Breakfast" : "Eat a Pitta, Bristol",
                "Attraction": "Wills Memorial Building And Tower Tours, Bristol; Bristol City Docks, Bristol; Bristol Museum & Art Gallery, Bristol",
                "Lunch": "Fishers Restaurant - Bristol, Bristol",
                "Dinner": "Urban Tandoor, Bristol",
                "Accommodation": "CozyUrbanLoft, Bristol",
                "Event": "-",
                "Point of Interest List": [
                    
                    " CozyUrbanLoft, visit from 09:00 to 10:00, nearest trasnsit: Downtown Transfer Center, 126.20m away;"
                    " Eat a Pitta, visit from 10:00 to 11:00, nearest transit: Home Depot, 6254489.95m away;"
                    " Wills Memorial Building And Tower Tours, visit from 11:00 to 14:00, nearest transit: Home Depot, 6253555.95m away;"
                    " Fishers Restaurant - Bristol, visit from 14:00 to 16:00, nearest transit: Home Depot, 6252544.49m away;"
                    " Bristol City Docks, visit from 16:00 to 18:00, nearest transit: Home Depot, 6253131.32m away;"
                    " Bristol Museum & Art Gallery, visit from 18:00 to 20:30, nearest transit: Home Depot, 6253515.21m away;"
                    " Urban Tandoor, visit from 20:30 to 22:00, nearest transit: Home Depot, 6254198.09m away;"
                    
                    " CozyUrbanLoft, visit from 22:00 to 09:00, nearest trasnsit: Downtown Transfer Center, 126.20m away."
                    
                ]
            },
            "Day 3": {
                "Current City": "from Bristol to Chattanooga", #travel from 1st_dest_city to 2nd_dest_city
                "Transportation": "Self-driving, Duration: 249.65166666666667 mins, Distance: 360.1764 km, Estimated Cost: $18.01", #we'll self deive from san luis obispo to san barbara 
                "Breakfast": "Cafe Bristol, Bristol", #skipped breakfast
                "Attraction": "Moon Pie General Store, Chattanooga",
                "Lunch": "-", #skipped
                "Dinner": "Firebirds Wood Fired Grill, Chattanooga",
                "Accommodation": "The Lookout Mountain, Chattanooga",
                "Event": "-",
                "Point of Interest List": [
                    " CozyUrbanLoft, visit from 09:00 to 10:00, nearest trasnsit: Downtown Transfer Center, 126.20m away;"
                    " Cafe Bristol, visit from 10:00 to 11:30, nearest transit: Home Depot, 7679840.27m away;"
                    #leaved from 3rd_dest_city
                    " The Lookout Mountain, stay from 17:00 to 17:30, nearest transit: Incline Railway TENN AVE + INCLINE, 63.48m away;"
                    " Moon Pie General Store, visit from 18:00 to 20:00, nearest transit: Broad & Jack's Alley, 46.95m away;"
                    " Firebirds Wood Fired Grill, visit from 20:30 to 22:30, nearest transit: Gunbarrel & Bus Shelter-1, 103.28m away;"
                    " The Lookout Mountain, stay from 22:30 to 09:30, nearest transit: Incline Railway TENN AVE + INCLINE, 63.48m away."
                    
                ]
            },
            "Day 4": {
                "Current City": "Chattonooga", #now explore dest_city_3
                "Transportation": "-", #no travel today 
                "Breakfast" : "Bluegrass Gril, Chattonooga",
                "Attraction": "The Lookout Mountain, Chattanooga; Chattanooga Zoo, Chattanooga; Chattanooga Ghost Tours, Chattanooga",
                "Lunch": "Zaya 1943 Korean Steakhouse, Chattanooga",
                "Dinner": "Ruth's Chris Steak House, Chattanooga",
                "Accommodation": "",
                "Event": "-",
                "Point of Interest List": [
                    " The Lookout Mountain, stay from 09:30 to 10:00, nearest transit: Incline Railway TENN AVE + INCLINE, 63.48m away;"
                    " Bluegrass Grill, visit from 10:00 to 11:00, nearest transit: MAIN + ROSSVILLE AVE, 46.22m away;"
                    " Chattanooga Zoo, visit from 11:00 to 14:00, nearest transit: Holtzclaw & 5th-1, 123.88m away;"
                    " Zaya 1943 Korean Steakhouse, visit from 14:00 to 16:00, nearest transit: MANUFACTURERS RD + CHEROKEE BLVD, 152.90m away;"
                    " Coolidge Park, visit from 16:00 to 19:30, nearest transit: Frazier & Forrest, 132.99m away;"
                    " Ruth's Chris Steak House, visit from 20:00 to 22:00, nearest transit: HAMILTON PLACE BLVD + BAMS, 315.44m away;"
                    " The Lookout Mountain, stay from 22:30 to 09:00, nearest transit: Incline Railway TENN AVE + INCLINE, 63.48m away."
                     
                ]
            },
            "Day 5": {
                "Current City": "from Chattanooga to Nashville", #travel 2nd_dest_city to 3rd_dest_city
                "Transportation": "Self-driving, Duration: 150.45166666666668 mins, Distance: 213.5283 km, Estimated Cost: $10.68", # remarks: not feasible to drive back from Santa Barbara to New York 
                "Breakfast": "Frothy Monkey, Chattanooga", #
                "Attraction": "The Lookout Mountain Incline Railway, Chattanooga; Grand Ole Opry, Nsshville",
                "Lunch": "-", #skipped
                "Dinner": "Luogo, Nashville",
                "Accommodation": "The Modern Johnny Nash-Walk To Broadway- HOT POOL, Nashville",
                "Event": "-",
                "Point of Interest List": [
                    " The Lookout Mountain, stay from 09:00 to 10:00, nearest transit: Incline Railway TENN AVE + INCLINE, 63.48m away;"
                    " Frothy Monkey, visit from 10:00 to 11:30, nearest transit: SHUTTLE PARK SOUTH, 58.96m away;"
                    " The Lookout Mountain Incline Railway, visit from 11:30 to 13:00, nearest transit: TENN AVE + INCLINE, 63.48m away;"
                    #leaved fro 3rd_dest_city i.e Cedar Rapids
                    " The Modern Johnny Nash-Walk To Broadway- HOT POOL, stay from 16:00 to 17:00, nearest transit: LAFAYETTE ST & EWING AVE SB, 176.49m away;"
                    " Grand Ole Opry, visit from 17:00 to 20:00, nearest transit: OPRY MILLS DR & GENERAL JACKSON'S, 377.07m away;"
                    " Luogo, visit from 20:30 to 22:00, nearest transit: 12TH AVE & LAUREL ST NB, 86.33m away"
                    " The Modern Johnny Nash-Walk To Broadway- HOT POOL, stay from 22:00 to 09:00, nearest transit: LAFAYETTE ST & EWING AVE SB, 176.49m away."

                    
                ]
            },
        "Day 6": {
                "Current City": "Nashville", #now in 2nd_dest city
                "Transportation": "-",
                "Breakfast": "1 Kitchen, Nashville", #American
                "Attraction": "Centennial Park, Nashville, RCA Studio B, Nashville; Country Music Hall of Fame and Museum, Nashville; Cooter’s Museum and Store, Nashville",
                "Lunch": "The Catbird Seat, Nashvile",
                "Dinner": "Old Hickory Steakhouse, Nashville",
                "Accommodation": "The Modern Johnny Nash-Walk To Broadway- HOT POOL, Nashville",
                "Event": "-",
                "Point of Interest List": [
                    " The Modern Johnny Nash-Walk To Broadway- HOT POOL, stay from 08:00 to 09:00, nearest transit: LAFAYETTE ST & EWING AVE SB, 176.49m away;"
                    " 1 Kitchen, visit from 09:00 to 10:00, nearest transit: 8TH AVE S & DEMONBREUN ST SB, 67.82m away;"
                    " Centennial Park, visit from 10:00 to 12:30, nearest transit: WEST END AVE & 27TH AVE S WB, 441.64m away;"
                    " RCA Studio B, visit from 12:30 to 14:00, nearest transit: BROADWAY AVE & 19TH AVE S EB, 338.29m away;"
                    " The Catbird Seat, visit from 14:00 to 15:30, nearest transit: BROADWAY AVE & 17TH AVE S EB, 189.47m away;"
                    " Country Music Hall of Fame and Museum, visit from 16:00 to 19:00, nearest transit: CONVENTION CENTER STATION OUTBOUND, 106.41m away;"
                    " Cooter’s Museum and Store Nashville, visit from 19:00 to 20:30, nearest transit: MCGAVOCK PIKE & MUSIC VALLEY DR WB, 109.02m away;"
                    " Old Hickory Steakhouse, visit from 20:30 to 22:00, nearest transit: OPRY MILLS DRIVE & WARDROBE BLDNG, 483.51m away;"
                    " The Modern Johnny Nash-Walk To Broadway- HOT POOL, stay from 22:00 to 08:00, nearest transit: LAFAYETTE ST & EWING AVE SB, 176.49m away."
                ]
            },
        "Day 7": {
                "Current City": "from Nashville to Boston", #from 3rd_dest_city to origin_city
                "Transportation": "Flight Number: F0260331, from Nashville to Boston, Departure Time: 12:21, Arrival Time: 15:36", # remarks:  feasible to drive 
                "Breakfast": "The Bluebird Cafe, Nashville",
                "Attraction": "Belmont Mansion, Nashville",
                "Lunch": "-",
                "Dinner": "-",
                "Accommodation": "The Modern Johnny Nash-Walk To Broadway- HOT POOL, Nashville",
                "Event": "-",
                "Point of Interest List": [
                    " The Modern Johnny Nash-Walk To Broadway- HOT POOL, stay from 08:00 to 09:00, nearest transit: LAFAYETTE ST & EWING AVE SB, 176.49m away;"
                    " The Bluebird Cafe, visit from 09:00 to 10:00, nearest transit: RICHARD JONES RD & HILLSBORO PIKE W, 383.04m away;"
                    " Belmont Mansion, visit from 10:00 to 12:00, nearest transit: WEDGEWOOD AVE & 16TH AVE EB, 92.02m away."
                    #leaved for Boston
                    
                ]
        
    }

        
              

        
        # Add remaining days as needed
    }

    # Print the travel plan
    print("\nAnnotated Travel Plan:")
    for day, details in travel_plan.items():
        print(f"\n{day}:")
        for key, value in details.items():
            if isinstance(value, list):
                print(f"{key}:")
                for item in value:
                    print(f"  {item}")
            else:
                print(f"{key}: {value}")

except KeyError:
    print("Column 'reference_information' does not exist in the file.")
except IndexError:
    print(f"Row {row_number} does not exist in the file.")
except json.JSONDecodeError as e:
    print(f"JSON decoding error for row {row_number}: {e}")
# Out:
# Row 159 - Keys and Content in 'reference_information':
#
# Entry 1:
#   Description: Attractions in Bristol
#   Content: name subcategories visit_duration address latitude longitude website
# Wills Memorial Building And Tower Tours ['Sights & Landmarks'] 3.0 Queens Rd, Bristol BS8 1RJ England 51.456036 -2.604578 http://www.facebook.com/willstowertours
# Bristol Museum & Art Gallery ['Shopping', 'Museums'] 2.25 Queens Road Clifton, Bristol BS8 1RL England 51.45623 -2.605093 http://www.bristolmuseums.org.uk/
# Blackbeard to Banksy the Ultimate Bristol Walking Tour ['Tours'] 3.0 College Green main entrance of the Cathedral, Bristol BS1 5TJ England 51.45186 -2.600728 http://blackbeard2banksy.com
# Escape Hunt Bristol ['Fun & Games'] 1.5 Cabot Circus, Bristol BS1 3BX England 51.458496 -2.585342 http://escapehunt.com/uk/bristol/?utm_campaign=&utm_source=TripAdvisor&utm_medium=referral&utm_content=engagement
# ...
